# %%
# ! pip install pyvisa
# ! pip install toml
# ! pip install html5lib
! pip install rasterio fiona
# Out:
# Requirement already satisfied: rasterio in d:\programdata\anaconda3\envs\llm_geo\lib\site-packages (1.3.9)
# Requirement already satisfied: fiona in d:\programdata\anaconda3\envs\llm_geo\lib\site-packages (1.9.4)
# Requirement already satisfied: affine in d:\programdata\anaconda3\envs\llm_geo\lib\site-packages (from rasterio) (2.4.0)
# Requirement already satisfied: attrs in d:\programdata\anaconda3\envs\llm_geo\lib\site-packages (from rasterio) (23.1.0)
# Requirement already satisfied: certifi in d:\programdata\anaconda3\envs\llm_geo\lib\site-packages (from rasterio) (2023.7.22)
# Requirement already satisfied: click>=4.0 in d:\programdata\anaconda3\envs\llm_geo\lib\site-packages (from rasterio) (8.1.7)
# Requirement already satisfied: cligj>=0.5 in d:\programdata\anaconda3\envs\llm_geo\lib\site-packages (from rasterio) (0.7.2)
# Requirement already satisfied: numpy in d:\programdata\anaconda3\envs\llm_geo\lib\site-packages (from rasterio) (1.26.0)
# Requirement already satisfied: snuggs>=1.4.1 in d:\programdata\anaconda3\envs\llm_geo\lib\site-packages (from rasterio) (1.4.7)
# Requirement already satisfied: click-plugins in d:\programdata\anaconda3\envs\llm_geo\lib\site-packages (from rasterio) (1.1.1)
# Requirement already satisfied: setuptools in d:\programdata\anaconda3\envs\llm_geo\lib\site-packages (from rasterio) (68.2.2)
# Requirement already satisfied: six in d:\programdata\anaconda3\envs\llm_geo\lib\site-packages (from fiona) (1.16.0)
# Requirement already satisfied: colorama in d:\programdata\anaconda3\envs\llm_geo\lib\site-packages (from click>=4.0->rasterio) (0.4.6)
# Requirement already satisfied: pyparsing>=2.1.6 in d:\programdata\anaconda3\envs\llm_geo\lib\site-packages (from snuggs>=1.4.1->rasterio) (3.1.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %load_ext autoreload
# %autoreload 2
import os    
import sys    
import time
import pprint
import json
from bs4 import BeautifulSoup
import requests
import json
import toml

# %%
from bs4 import BeautifulSoup
import json
import copy
import pprint

# url = r'https://grass.osgeo.org/grass84/manuals/i.aster.toar.html'
# url = r'https://grass.osgeo.org/grass84/manuals/v.db.join.html'
url = r'https://grass.osgeo.org/grass84/manuals/r.carve.html'
url = r'https://grass.osgeo.org/grass84/manuals/i.albedo.html'
url = r'https://grass.osgeo.org/grass84/manuals/i.atcorr.html'

def get_response(url):
    response = requests.get(url)

    # Check if the request was successful
    if response.status_code == 200:
        html_content = response.content
        # Parse the HTML content using BeautifulSoup
        soup = BeautifulSoup(html_content, 'html5lib')
        # soup = BeautifulSoup(html_content, 'html.parser')

        # Now you can work with 'soup' to extract the relevant sections
        # Example: printing the title of the page
        print("Title: ", soup.title.get_text())

    else:
        print(f"Failed to retrieve the page. Status code: {response.status_code}")
        
    return soup


url = r'https://grass.osgeo.org/grass84/manuals/r.carve.html'
soup = get_response(url)
# soup
# Out:
# Title:  r.carve - GRASS GIS manual

# %%
from bs4 import BeautifulSoup

# Sample HTML content
html_content = """
<html>
  <body>
    <p>This is an example with a bold tag: <b>-r</b> that needs to be replaced.</p>
  </body>
</html>
"""

# Parse the HTML content
soup = BeautifulSoup(html_content, 'html5lib')

# Find the <b> tag that contains the text "-r"
bold_tag = soup.find('b')

# Replace the <b> tag with plain text " -r "
if bold_tag:
    bold_tag.replace_with(" -r ")

# Print the modified HTML
print(soup.prettify())
# Out:
# <html>
#  <head>
#  </head>
#  <body>
#   <p>
#    This is an example with a bold tag:
#    -r
#    that needs to be replaced.
#   </p>
#  </body>
# </html>

# %%
# Dictionary to hold headers and their associated content
content_dict = {}


# grass_html = Extract_GRASS_doc(soup)

def get_keywords_content(header, tool_info):
    keywords = []
    next_sibling = header.find_next_sibling()
    
    while next_sibling and next_sibling.name not in ['h2', 'h3', 'h4']:
        if next_sibling.name in ['a', 'p', 'em', 'div',  'b', 'dd', 'dt', 'dl', 'pre']:
            sibling_text = next_sibling.get_text(strip=True)            
            keywords.append(sibling_text) 
            
        next_sibling = next_sibling.find_next_sibling()  
    tool_info['keywords'] = keywords
             
    return tool_info

def get_synopsis_content(header, tool_info):
    content_lines = []
    
    # get tool name
    next_sibling = header.find_next_sibling()
    sibling_text = next_sibling.get_text(strip=True)    
    content_lines.append(sibling_text)
    
    # get tool --help
    next_sibling = next_sibling.find_next_sibling()    
    sibling_text = next_sibling.get_text(strip=True)    
    content_lines.append(sibling_text)
    
    
    next_sibling = next_sibling.find_next_sibling() # skip a <br>
    
    # get tool command    
    next_sibling = next_sibling.find_next_sibling()    
    sibling_text = next_sibling.get_text(strip=True)    
    content_lines.append(sibling_text)
     
    tool_info['synopsis'] = content_lines
             
    return tool_info

def get_flags_content(header, tool_info):
    # save the flags as a list to keep the order information.
    content_list = []   
    dl = header.find_next_sibling() # get a dl tag
    
    for tag in dl.find_all(['dt', 'dd']):
        if tag.name in ['dt']:
            # print("tag:", tag)
            line = tag.get_text(strip=True) 
            
        if tag.name in ['dd']:
            # print("tag:", tag)
            line = tag.get_text(strip=True)    
            line = "    " + line
            
        content_list.append(line)

    tool_info['Flags'] = content_list
             
    return tool_info

def get_flags_content_dict(header, tool_info):# not fit for the multi-line!!!
    # save the flags as a dictionary, but will lost the order information.
    content_dict = {}    
    next_sibling = header.find_next_sibling()  
    dl = next_sibling.find('dl')
    # Iterate over <dt> and <dd> tags
    for dt in next_sibling.find_all('dt'):
        term = dt.get_text(strip=True)  # Get the text in <dt>
        dd = dt.find_next_sibling('dd')  # Get the corresponding <dd>
        if dd:
            description = dd.get_text(strip=True)  # Get the text in <dd>
            content_dict[term] = description
     
    tool_info['Flags'] = content_dict
             
    return tool_info

def get_parameters_content_dict(header, tool_info):  # not fit for the multi-line!!!
    # save the parameters as a dictionary, but will lost the order information.
    content_dict = {}    
    next_sibling = header.find_next_sibling()  
    dl = next_sibling.find('dl')
    # Iterate over <dt> and <dd> tags
    for dt in next_sibling.find_all('dt'):
        term = dt.get_text(strip=True)  # Get the text in <dt>
        dd = dt.find_next_sibling('dd')  # Get the corresponding <dd>
        if dd:
            description = dd.get_text(strip=True)  # Get the text in <dd>
            content_dict[term] = description
     
    tool_info['Parameters'] = content_dict
             
    return tool_info

def get_parameters_content(header, tool_info):
    # save the parameters as a list, keep the order information.
    content_list = []   
    dl = header.find_next_sibling() # get a dl tag
    
    for tag in dl.find_all(['dt', 'dd']):
        if tag.name in ['dt']:
            # print("tag:", tag)
            line = tag.get_text(strip=True) 
            
        if tag.name in ['dd']:
            # print("tag:", tag)
            line = tag.get_text(strip=True)    
            line = "    " + line
            
        content_list.append(line)

    tool_info['Parameters'] = content_list
             
    return tool_info

 
def get_notes_content(header, tool_info):
    paragraphs = []
    paragraph = ""
    next_sibling = header.next_sibling
    # print("next_sibling:", next_sibling.name, next_sibling.get_text(strip=True))
    
    while next_sibling and next_sibling.name not in ['h2', 'h3', 'h4']:
        if next_sibling.name in ['a', 'em',  'b', 'dd', 'dt', 'dl']:
            sibling_text = next_sibling.get_text(strip=True)            
            paragraph += sibling_text             
            
        if isinstance(next_sibling, str):
            sibling_text = next_sibling.get_text().replace('\n', '')
            
            # print("     string next_sibling:", next_sibling.name, next_sibling.get_text(strip=True))
            
            if next_sibling.next_sibling.name in ["h2", "h3", "h4"]:
                paragraphs.append(sibling_text)               
            else:                
                paragraph += sibling_text
                
            if next_sibling.next_sibling.name in ['pre', 'h2', 'h3', 'h4']:  # end
                paragraphs.append(paragraph) 
                paragraph = ""
            
        if next_sibling.name in ['p']:
            sibling_text = next_sibling.get_text(strip=True)   
            paragraphs.append(paragraph)            
            paragraph = ""
            paragraphs.append(sibling_text)            
            
        if next_sibling.name in ['div']:
            
            if paragraph:
                paragraphs.append(paragraph)
                # print("paragraphs:", paragraphs)
                paragraph = ""
            
            sibling_text = next_sibling.get_text(strip=False)
            # print("sibling_text:", sibling_text)
 
  
            # print("paragraphs:", paragraphs)
            
  
            paragraphs.append(sibling_text)
            # print("paragraphs:", paragraphs)
              
        # next_sibling = next_sibling.find_next_sibling()  # cannot find strings that are not enclosed in tags
        next_sibling = next_sibling.next_sibling  # can find strings that are not enclosed in tags
        # print("next_sibling:", next_sibling.name, next_sibling.get_text(strip=True))
        
    tool_info['notes'] = paragraphs
             
    return tool_info

def get_see_also_content(header, tool_info):
    links = []
    paragraphs = []
    next_sibling = header.find_next_sibling()
    # print("header:", header, header.name)
    # print("next_sibling:", next_sibling.name, next_sibling,  next_sibling.get_text(strip=True))
    # print("next_sibling:", header.find_next_sibling())
    
    while next_sibling and next_sibling.name not in ['h2', 'h3', 'h4']:
        if next_sibling.name in ['a', 'em']:
            sibling_text = next_sibling.get_text(strip=True)            
            links =   sibling_text.split(",")   
            paragraphs += links
            
        if next_sibling.name in ['p']:
            # sibling_text = next_sibling.get_text(strip=True)             
            convert_to_markdown(next_sibling)
                
            sibling_text = next_sibling.get_text(strip=True) 
            paragraphs.append(sibling_text)  
            
        next_sibling = next_sibling.find_next_sibling()  # cannot find strings that are not enclosed in tags
        
        # .next_sibling: This method only navigates the immediate next sibling node in the document. The sibling could be another tag, a text node, or even whitespace. If there is any text (including line breaks, spaces, etc.) between the <h2> and <em> tags, .next_sibling will return that text or whitespace instead of the <em> tag.
             
    tool_info['see_also'] = paragraphs
             
    return tool_info

# Function to convert HTML content to markdown
def convert_to_markdown(tag):
    # Convert links to markdown format
    for a_tag in tag.find_all('a'):
        link_text = a_tag.get_text()
        link_url = a_tag['href']
        # Replace the <a> tag with markdown-formatted link
        a_tag.replace_with(f'[{link_text}]({link_url})')
    
    # Return the markdown-converted paragraph text
    return tag.get_text()

 
def get_author_content(header, tool_info):
     
    next_sibling = header.next_sibling
    
    # print("next_sibling:", next_sibling.name, next_sibling,  next_sibling.get_text(strip=True))
    
    paragraphs = []
    paragraph = ""
    
    while next_sibling and next_sibling.name not in ['h2', 'h3', 'h4']:
    
        if isinstance(next_sibling, str):
            sibling_text = next_sibling.get_text(strip=True) # .replace('\n', '')
            paragraph += sibling_text
              
        next_sibling = next_sibling.next_sibling  # can find strings that are not enclosed in tags
        
    paragraphs.append(paragraph)         
    tool_info['author'] = paragraphs
             
    return tool_info

def get_source_code_content(header, tool_info):
     
    next_sibling = header.next_sibling
    
    # print("next_sibling:", next_sibling.name, next_sibling,  next_sibling.get_text(strip=True))
    
    paragraphs = []
    paragraph = ""
    
    while next_sibling and next_sibling.name not in ['h2', 'h3', 'h4', 'hr']:
    
        if isinstance(next_sibling, str):
            sibling_text = next_sibling.get_text(strip=True) # .replace('\n', '')
            paragraph += sibling_text
            
        if next_sibling.name in ['p']:
        
            convert_to_markdown(next_sibling)
                
            sibling_text = next_sibling.get_text(strip=True) 
            paragraphs.append(sibling_text)  
            
            # sibling_text = next_sibling.get_text(strip=True) # .replace('\n', '')
            # paragraph += sibling_text
              
        next_sibling = next_sibling.next_sibling  # can find strings that are not enclosed in tags
        
    paragraphs.append(paragraph)         
    tool_info['source_code'] = paragraphs
             
    return tool_info
 


def get_name_content(header, tool_info):
    paragraph = ""
    paragraphs = []
    # print("next_sibling:", header.name, header.get_text(strip=True))
    next_sibling = header.next_sibling
    next_sibling = next_sibling.next_sibling   # do not understand, but need to do next_sibling twice
    # print("next_sibling:", next_sibling.name, next_sibling.get_text(strip=True))
    
    sibling_text = next_sibling.get_text(strip=True)
    tool_info['name'] = sibling_text
    
    paragraph += sibling_text
    
    
    while next_sibling and next_sibling.name not in ['h2', 'h3', 'h4']:
        if next_sibling.name in ['a', 'p', 'em', 'div',  'b', 'dd', 'dt', 'dl', 'pre']:
            sibling_text = next_sibling.get_text(strip=True)
            paragraph += sibling_text
            
        # Handle inline text outside of tags
        if next_sibling.next_sibling and isinstance(next_sibling.next_sibling, str):
            sibling_text = next_sibling.next_sibling.get_text(strip=True)
            # print("     string next_sibling:", next_sibling.name, next_sibling.get_text(strip=True))
            paragraph += sibling_text
            
        if next_sibling.name in ['br',  'h3', 'h4'', dl', 'ul'] or (next_sibling.next_sibling.name in ['h2']):
            paragraphs.append(paragraph)
            paragraph = ""
            sibling_text = next_sibling.next_sibling.get_text(strip=True)
            paragraph = sibling_text
            # print("     string next_sibling:", next_sibling.name, next_sibling.get_text(strip=True))
            # paragraph += sibling_text
            
            
        next_sibling = next_sibling.next_sibling     
        # print("next_sibling:", next_sibling.name, next_sibling.get_text(strip=True))
        
    tool_info['brief_description'] = paragraphs # not remove the starting "- ". 
             
    return tool_info

def get_examples_content(header, tool_info):
     
    next_sibling = header.next_sibling  # can find strings that are not enclosed in tags
    
    # print("next_sibling:", next_sibling.name, next_sibling,  next_sibling.get_text(strip=True))
    
    paragraphs = []
    paragraph = ""
    
    while next_sibling and next_sibling.name not in ['h2']:
    
        if isinstance(next_sibling, str):
            sibling_text = next_sibling.get_text(strip=False).replace("\n", " ") 
            paragraph += sibling_text
            
        if next_sibling.name in ['a']:
            sibling_text = next_sibling.get_text(strip=True) # .replace('\n', '')
            paragraph += f" {sibling_text} "
            
        if next_sibling.name in ['p']:
        
            # convert_to_markdown(next_sibling)
                
            sibling_text = next_sibling.get_text(strip=False).replace("\n", " ") 
            # print("next_sibling.name:", next_sibling.name, next_sibling.get_text(strip=True))
            

            if sibling_text:
                if paragraph:
                    paragraphs.append(paragraph)  
                    paragraphs.append("")  
                    paragraph = ""
                    
                paragraphs.append(sibling_text) 
                paragraphs.append("")  
                paragraph = ""
            
        if next_sibling.name in ['h3']:
            sibling_text = next_sibling.get_text(strip=True) # .replace('\n', '')
            sibling_text = f"**{sibling_text}**"
            paragraphs.append(sibling_text) 
            
        if next_sibling.name in ['div']:     
            # print(next_sibling)
            # print("next_sibling['class']:", next_sibling['class']) 
            try:
                if 'code' in next_sibling['class']:
                    # print("next_sibling['class']:", next_sibling['class']) 
                    # finish the previous paragraph
                    if paragraph:
                        paragraphs.append(paragraph)                          
                        paragraph = ""

                    # form a markdown code block
                    # paragraphs.append("")
                    paragraphs.append("```code")
                    sibling_text = next_sibling.get_text(strip=True) 
                    lines = sibling_text.split("\n")
                    # print(lines)
                    paragraphs +=  lines 
                    paragraphs.append("```")
                    paragraphs.append("")
            except Exception as e:
                # print("Error in processing 'div' tag: ", tool_info['name'], e)
                pass
                
                # continue

                # sibling_text = next_sibling.get_text(strip=True) # .replace('\n', '')
                # paragraph += sibling_text
              
        next_sibling = next_sibling.next_sibling  # can find strings that are not enclosed in tags
        # print("next_sibling.name:", next_sibling.name, next_sibling.get_text(strip=True))
        
    paragraphs.append(paragraph)         
    tool_info['examples'] = paragraphs
             
    return tool_info


def get_tool_info_from_page(url):
    
    soup = get_response(url)

    tool_info = {}

    for header in soup.find_all(['h2', 'h3', 'h4']):
        header_text = header.get_text(strip=True)

        # print(header_text)     

        if header_text == 'NAME':
            get_name_content(header, tool_info)

        if header_text == 'KEYWORDS':
            get_keywords_content(header, tool_info)

        if header_text == 'SYNOPSIS':
            get_synopsis_content(header, tool_info)

        if header_text == 'Flags:':
            get_flags_content(header, tool_info)

        if header_text == 'Parameters:':
            get_parameters_content(header, tool_info)

        if header_text == 'DESCRIPTION':
            get_description_content(header, tool_info)

        if header_text == 'NOTES':
            get_notes_content(header, tool_info)
            
        if header_text == 'EXAMPLES' or (header_text == 'EXAMPLE'):
            get_examples_content(header, tool_info)

        if header_text == 'SEE ALSO':
            get_see_also_content(header, tool_info)

        if header_text == 'AUTHOR':
            get_author_content(header, tool_info)      

        if header_text == 'SOURCE CODE':
            get_source_code_content(header, tool_info)   


    # pprint.pprint(tool_info, width=800)
    tool_info['url'] = url
    return tool_info, soup

# Function to convert HTML content to markdown
def clean_tag(tag):
    # Convert links to markdown format
    for a_tag in tag.find_all('b'):
        text = a_tag.get_text()
        # Replace the <a> tag with markdown-formatted link
        print("a_tag:", a_tag, text)
        print(f' {text} ')
        a_tag.replace_with(f' {text} ')
        print("a_tag:", a_tag)
    
def get_description_content(header, tool_info):
    paragraphs = []
    paragraph = ""
    next_sibling = header.next_sibling
    # print("next_sibling:", next_sibling.name, next_sibling.get_text(strip=True))
    
    while next_sibling and next_sibling.name not in ['h2']:
        if next_sibling.name in ['a', 'em', 'b', 'dd', 'dt', 'dl']:
            # print("next_sibling.name:", next_sibling.name)
            sibling_text = next_sibling.get_text(strip=True)   
            paragraph += sibling_text

            # print("sibling_text:", sibling_text)
#             print("paragraph:", paragraph)
            
        # if next_sibling.next_sibling and isinstance(next_sibling.next_sibling, str):
        if isinstance(next_sibling, str):
            sibling_text = next_sibling.get_text().replace('\n', ' ')
            paragraph += sibling_text
            
            
            # print("      string， sibling_text:", sibling_text)
            
            if next_sibling.next_sibling.name in ["h2", "h3", "h4", "p", "ul"]:
                paragraphs.append(paragraph + "\n" )
                paragraphs.append("")
                paragraph = ""
                
        if next_sibling.name in ['p']:

            sibling_text = next_sibling.get_text(strip=False).replace("\n\n", "\n").replace("\n", " ") 
            
            if sibling_text:            
                if paragraph:
                    paragraphs.append(paragraph + "\n"  )
                    paragraphs.append("")
                    paragraph = ""
                    
                paragraphs.append(sibling_text)  
                paragraphs.append("")
                paragraph = ""

            
        if next_sibling.name in ['div']:     
            # print(next_sibling)
            
            try:
                if 'code' in next_sibling['class']:
                    # print("next_sibling['class']:", next_sibling['class']) 
                    # finish the previous paragraph
                    if paragraph:
                        paragraphs.append(paragraph + "\n" )  
                        paragraphs.append("")
                        paragraph = ""
                        # print("next_sibling['class']:", next_sibling['class'])

                    # form a markdown code block
                    # paragraphs.append("")
                    # print("next_sibling['class']:", next_sibling['class']) 
                    paragraphs.pop()
                    paragraphs.append("```code")
                    sibling_text = next_sibling.get_text(strip=True) 
                    lines = sibling_text.split("\n")
                    # print(lines)
                    paragraphs +=  lines 
                    paragraphs.append("```")
                    paragraphs.append("")
            except Exception as e:
                print("Error in processing 'div' tag: ", tool_info['name'], e)
                pass
            
                         
        if next_sibling.name in ['ul']:
            
            if paragraph:
                paragraphs.append(paragraph)
                # print("paragraphs:", paragraphs)
                paragraph = ""
            
            sibling_text = next_sibling.get_text(strip=False).replace("\n\n", "\n").replace("\n", " ")
            ulist = sibling_text.split('\n')
            
            # print("ulist:", ulist            
            # remove emptry strings
            ulist = [f"•{item}" for item in ulist if item]  # correct
            # print("ulist:", ulist)
            # ulist = [ for item in ulist if item]
            
            # print("paragraphs:", paragraphs)
            
            paragraphs += ulist
               
        # next_sibling = next_sibling.find_next_sibling()  # cannot find strings that are not enclosed in tags
        next_sibling = next_sibling.next_sibling  # can find strings that are not enclosed in tags
        # print("next_sibling:", next_sibling.name, next_sibling.get_text(strip=True))
        
    paragraphs.append(paragraph)
    paragraph = ""
        
    tool_info['description'] = paragraphs
             
    return tool_info

    
# url = r'https://grass.osgeo.org/grass84/manuals/r.carve.html'
url = r'https://grass.osgeo.org/grass84/manuals/i.atcorr.html'

# soup = get_response(url)    
    
tool_info, soup = get_tool_info_from_page(url)

# pprint.pprint(tool_info, width=800)
# print(tool_info['name'])
# print(tool_info['brief_description'])
# for line in tool_info['description']:
#     print(line)
    
tool_info['examples']

# %%
tool_info['description']
# Out:
# ['  i.atcorr performs atmospheric correction on the input raster map using the 6S algorithm (Second Simulation of Satellite Signal\nin the Solar Spectrum). A detailed algorithm description is available at the Land Surface\nReflectance Science Computing Facility website.  \n',
#  '',
#  'Important: Current region settings are ignored! The region is adjusted to cover the input raster map before the atmospheric correction is performed. The previous settings are restored afterwards. ',
#  '',
#  'If the -r flag is used, the input raster map is treated as reflectance. Otherwise, the input raster map is treated as radiance values and it is converted to reflectance at the i.atcorr runtime. The output data are always reflectance. ',
#  '',
#  'The satellite overpass time has to be specified in Greenwich Mean Time (GMT). ',
#  '',
#  'An example of the 6S parameters could be: ',
#  '```code',
#  '8                            - geometrical conditions=Landsat ETM+',
#  '2 19 13.00 -47.410 -20.234   - month day hh.ddd longitude latitude ("hh.ddd" is in decimal hours GMT)',
#  '1                            - atmospheric model=tropical',
#  '1                            - aerosols model=continental',
#  '15                           - visibility [km] (aerosol model concentration)',
#  '-0.600                       - mean target elevation above sea level [km] (here 600 m asl)',
#  '-1000                        - sensor height (here, sensor on board a satellite)',
#  '64                           - 4th band of ETM+ Landsat 7',
#  '```',
#  '',
#  '  If the position is not available in longitude-latitude (WGS84), the m.proj conversion module can be used to reproject from a different reference system.  \n',
#  '',
#  '']

# %%
# for line in tool_info['examples']:
#     print(line)
    
# for line in tool_info['description']:
#     print(line)

# %%
# # 
# for line in tool_info['examples']:
#     print(line)

# %%
GRASS_tools =["g.extension.list", "g.extension.manage", "i.albedo", "i.aster.toar", "i.atcorr", "i.biomass", "i.cca", "i.cluster", "i.colors.enhance", "i.eb.eta", "i.eb.evapfr", "i.eb.hsebal01.coords", "i.eb.netrad", "i.eb.soilheatflux", "i.emissivity", "i.evapo.mh", "i.evapo.pm", "i.evapo.pt", "i.evapo.time", "i.fft", "i.gensig", "i.gensigset", "i.group", "i.his.rgb", "i.ifft", "i.image.mosaic", "i.in.spotvgt", "i.landsat.acca", "i.landsat.toar", "i.maxlik", "i.modis.qc", "i.oif", "i.pansharpen", "i.pca", "i.rgb.his", "i.segment", "i.smap", "i.tasscap", "i.topo.coor.ill", "i.topo.corr", "i.vi", "i.zc", "m.cogo", "nviz", "r.basins.fill", "r.blend.combine", "r.blend.rgb", "r.buffer", "r.buffer.lowmem", "r.carve", "r.category", "r.category.out", "r.circle", "r.clump", "r.coin", "r.colors", "r.colors.out", "r.colors.stddev", "r.composite", "r.contour", "r.cost", "r.covar", "r.cross", "r.describe", "r.distance", "r.drain", "r.fill.dir", "r.fill.stats", "r.fillnulls", "r.flow", "r.geomorphon", "r.grow", "r.grow.distance", "r.gwflow", "r.his", "r.horizon", "r.horizon.height", "r.in.lidar", "r.in.lidar.info", "r.info", "r.kappa", "r.lake", "r.latlong", "r.li.cwed", "r.li.cwed.ascii", "r.li.dominance", "r.li.dominance.ascii", "r.li.edgedensity", "r.li.edgedensity.ascii", "r.li.mpa", "r.li.mpa.ascii", "r.li.mps", "r.li.mps.ascii", "r.li.padcv", "r.li.padcv.ascii", "r.li.padrange", "r.li.padrange.ascii", "r.li.padsd", "r.li.padsd.ascii", "r.li.patchdensity", "r.li.patchdensity.ascii", "r.li.patchnum", "r.li.patchnum.ascii", "r.li.pielou", "r.li.pielou.ascii", "r.li.renyi", "r.li.renyi.ascii", "r.li.richness", "r.li.richness.ascii", "r.li.shannon", "r.li.shannon.ascii", "r.li.shape", "r.li.shape.ascii", "r.li.simpson", "r.li.simpson.ascii", "r.mapcalc.simple", "r.mask.rast", "r.mask.vect", "r.mfilter", "r.mode", "r.neighbors", "r.null", "r.out.ascii", "r.out.gridatb", "r.out.mat", "r.out.mpeg", "r.out.png", "r.out.pov", "r.out.ppm", "r.out.ppm3", "r.out.vrml", "r.out.vtk", "r.out.xyz", "r.param.scale", "r.patch", "r.path", "r.path.coordinate.txt", "r.plane", "r.profile", "r.proj", "r.quant", "r.quantile", "r.quantile.plain", "r.random", "r.random.cells", "r.random.surface", "r.reclass", "r.reclass.area", "r.recode", "r.regression.line", "r.regression.multi", "r.relief", "r.relief.scaling", "r.report", "r.resamp.bspline", "r.resamp.filter", "r.resamp.interp", "r.resamp.rst", "r.resamp.stats", "r.resample", "r.rescale", "r.rescale.eq", "r.rgb", "r.ros", "r.series", "r.series.accumulate", "r.series.interp", "r.shade", "r.sim.sediment", "r.sim.water", "r.slope.aspect", "r.solute.transport", "r.spread", "r.spreadpath", "r.statistics", "r.stats", "r.stats.quantile.out", "r.stats.quantile.rast", "r.stats.zonal", "r.stream.extract", "r.sun.incidout", "r.sun.insoltime", "r.sunhours", "r.sunmask.datetime", "r.sunmask.position", "r.surf.area", "r.surf.contour", "r.surf.fractal", "r.surf.gauss", "r.surf.idw", "r.surf.random", "r.terraflow", "r.texture", "r.thin", "r.tile", "r.tileset", "r.to.vect", "r.topidx", "r.topmodel", "r.topmodel.topidxstats", "r.transect", "r.univar", "r.uslek", "r.usler", "r.viewshed", "r.volume", "r.walk.coords", "r.walk.points", "r.walk.rast", "r.water.outlet", "r.watershed", "r.what.color", "r.what.coords", "r.what.points", "v.buffer", "v.build.check", "v.build.polylines", "v.class", "v.clean", "v.cluster", "v.db.select", "v.decimate", "v.delaunay", "v.dissolve", "v.distance", "v.drape", "v.edit", "v.extract", "v.extrude", "v.generalize", "v.hull", "v.in.ascii", "v.in.dxf", "v.in.e00", "v.in.geonames", "v.in.lidar", "v.in.lines", "v.in.mapgen", "v.in.wfs", "v.info", "v.kcv", "v.kernel.rast", "v.kernel.vector", "v.lidar.correction", "v.lidar.edgedetection", "v.lidar.growing", "v.mkgrid", "v.neighbors", "v.net", "v.net.alloc", "v.net.allpairs", "v.net.bridge", "v.net.centrality", "v.net.components", "v.net.connectivity", "v.net.distance", "v.net.flow", "v.net.iso", "v.net.nreport", "v.net.path", "v.net.report", "v.net.salesman", "v.net.spanningtree", "v.net.steiner", "v.net.timetable", "v.net.visibility", "v.normal", "v.out.ascii", "v.out.dxf", "v.out.postgis", "v.out.pov", "v.out.svg", "v.out.vtk", "v.outlier", "v.overlay", "v.pack", "v.parallel", "v.patch", "v.perturb", "v.proj", "v.qcount", "v.random", "v.rast.stats", "v.reclass", "v.rectify", "v.report", "v.sample", "v.segment", "v.select", "v.split", "v.surf.bspline", "v.surf.idw", "v.surf.rst", "v.surf.rst.cvdev", "v.to.3d", "v.to.lines", "v.to.points", "v.to.rast", "v.transform", "v.type", "v.univar", "v.vect.stats", "v.voronoi", "v.voronoi.skeleton", "v.what.rast", "v.what.vect"]

# %%
# tool_info['examples']

# %%
from markdownify import markdownify

def make_synopsis_for_GRASS_TOML(tool_info):
    
    lines = tool_info['synopsis']
  
    synopsis_string = "\n".join(lines)
    # print(parameters_string)

    # Return the string enclosed in triple quotes
    # parameters_string = '"""\n' + parameters_string + '\n"""'
    return synopsis_string

def make_parameters_for_GRASS_TOML(tool_info):
    
    lines = tool_info['Parameters']
  
    parameters_string = "\n".join(lines)
    # print(parameters_string)

    # Return the string enclosed in triple quotes
    # parameters_string = '"""\n' + parameters_string + '\n"""'
    return parameters_string

def make_flags_for_GRASS_TOML(tool_info):
    
    lines = tool_info['Flags']
  
    flags_string = "\n".join(lines)
    # print(parameters_string)

    # Return the string enclosed in triple quotes
    # parameters_string = '"""\n' + parameters_string + '\n"""'
    return flags_string

def make_full_description_for_GRASS_TOML(tool_info):    
    lines = tool_info['description']  
    description_string = "\n".join(lines)
    if description_string[-2:] == "\n\n":
        # print("description_string[-2:]:", description_string[-2:] )
        description_string = description_string[:-2]
        
    if description_string[-3:] == "\n\n\n":
        # print("description_string[-2:]:", description_string[-2:] )
        description_string = description_string[:-3]
    if description_string[:2] == "  ":
        print("description_string[0]:", description_string[:2])
        description_string = description_string[2:]
        
    return description_string.replace("\n\n\n", "\n\n")

def make_examples_for_GRASS_TOML(tool_info):
    
    lines = tool_info.get('examples', None)
    
    if lines: 
        examples_string = "\n".join(lines).replace("\n    \n\n", "\n\n").replace("\n   \n\n", "\n\n").replace("\n  \n\n", "\n\n").replace("\n \n\n", "\n\n").replace("\n\n\n", "\n\n").replace("\n \n \n", "\n\n").replace("\n\n  \n", "\n\n").replace("\n\n   \n", "\n\n")
        if examples_string[-3:] == "\n\n\n":
            examples_string = examples_string[:-3]
        if examples_string[-2:] == "\n\n":
            examples_string = examples_string[:-2]
    else:
        examples_string = ""
         
    return examples_string

def make_markdown_for_GRASS_TOML(soup):
    
    markdown_content = markdownify(str(soup.find('div', id="container")))
    
    str_pos = markdown_content.find("DESCRIPTION\n")
    
    markdown_content = "\n" + markdown_content[str_pos:]
    
    ending_headers = ["TODO", "REFERENCES", "References", "SEE ALSO", "AUTHORS", "AUTHORS", "SOURCE CODE"]
    
    for h in ending_headers:
        str_pos = markdown_content.find(h + "\n")
        
        if str_pos > -1:
            markdown_content = markdown_content[:str_pos]
            
    markdown_content = "(This document is written in markdown format.) \n\n\n" +  markdown_content# .replace("\n\n\n", "\n\n").replace("\n\n\n", "\n\n").replace("\n\n\n", "\n\n").replace("\n\n\n", "\n\n")
               
    return markdown_content

def make_GRASS_TOML_file(tool_info, soup, fname):
    tool_toml = {}
    tool_toml['tool_ID'] = tool_info['name']
    tool_toml['tool_name'] = tool_info['name']    
    tool_toml['brief_description'] = '\n'.join(tool_info['brief_description'])
    # tool_toml['full_description'] = make_full_description_for_GRASS_TOML(tool_info)
    tool_toml['synopsis'] = make_synopsis_for_GRASS_TOML(tool_info)
    tool_toml['flags'] = make_flags_for_GRASS_TOML(tool_info)
    tool_toml['parameters'] = make_parameters_for_GRASS_TOML(tool_info)
    # tool_toml['url'] = tool_info['url']
    
     
    # print("tool_toml['parameters'] :", tool_toml['parameters'] )
    # print("tool_toml['flags'] :", tool_toml['flags'] )
    # tool_toml['outputs'] = make_outputs_for_GRASS_TOML(tool_info)
    # tool_toml['code_example'] = make_examples_for_GRASS_TOML(tool_info)
     
    tool_toml['document'] =  make_markdown_for_GRASS_TOML(soup)
    
    with open(fname, 'w', encoding='utf-8') as f:  # charmap' codec can't encode character
        toml_str = toml.dump(tool_toml, f)
        
    # toml_str = toml.dumps(tool_toml)
    # print("toml_str:", toml_str)
    return toml_str
 
 
save_dir = r'D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml'
os.makedirs(save_dir, exist_ok=True)

for idx, tool in enumerate(GRASS_tools[2:]):
    print(f"Processing: {idx + 1} / {len(GRASS_tools)}, {tool} ")
    url = f"https://grass.osgeo.org/grass84/manuals/{tool}.html"
    # url = r'https://grass.osgeo.org/grass84/manuals/v.db.join.html'
    # url = r'https://grass.osgeo.org/grass84/manuals/r.carve.html'
    # url = r'https://grass.osgeo.org/grass84/manuals/i.atcorr.html'

    print("    URL:", url)
  
    count = 0

    try:
        tool_info, soup = get_tool_info_from_page(url)    
         
        tool_name = tool

        fname = os.path.join(save_dir, f"{tool_name}.toml")
        
        # print("fname:", fname)
#         
        toml_str = make_GRASS_TOML_file(tool_info, soup, fname) 
        print("Saved at:", fname)
        
        count += 1

        print(f"{count} tool_name:", tool)
        # break
    except Exception as e:

        print("error:", e)
        continue
        
    # break
# Out:
# Processing: 1 / 306, i.albedo
#     URL: https://grass.osgeo.org/grass84/manuals/i.albedo.html
# Title:  i.albedo - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\i.albedo.toml
# 1 tool_name: i.albedo
# Processing: 2 / 306, i.aster.toar
#     URL: https://grass.osgeo.org/grass84/manuals/i.aster.toar.html
# Title:  i.aster.toar - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\i.aster.toar.toml
# 1 tool_name: i.aster.toar
# Processing: 3 / 306, i.atcorr
#     URL: https://grass.osgeo.org/grass84/manuals/i.atcorr.html
# Title:  i.atcorr - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\i.atcorr.toml
# 1 tool_name: i.atcorr
# Processing: 4 / 306, i.biomass
#     URL: https://grass.osgeo.org/grass84/manuals/i.biomass.html
# Title:  i.biomass - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\i.biomass.toml
# 1 tool_name: i.biomass
# Processing: 5 / 306, i.cca
#     URL: https://grass.osgeo.org/grass84/manuals/i.cca.html
# Title:  i.cca - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\i.cca.toml
# 1 tool_name: i.cca
# Processing: 6 / 306, i.cluster
#     URL: https://grass.osgeo.org/grass84/manuals/i.cluster.html
# Title:  i.cluster - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\i.cluster.toml
# 1 tool_name: i.cluster
# Processing: 7 / 306, i.colors.enhance
#     URL: https://grass.osgeo.org/grass84/manuals/i.colors.enhance.html
# Title:  i.colors.enhance - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\i.colors.enhance.toml
# 1 tool_name: i.colors.enhance
# Processing: 8 / 306, i.eb.eta
#     URL: https://grass.osgeo.org/grass84/manuals/i.eb.eta.html
# Title:  i.eb.eta - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\i.eb.eta.toml
# 1 tool_name: i.eb.eta
# Processing: 9 / 306, i.eb.evapfr
#     URL: https://grass.osgeo.org/grass84/manuals/i.eb.evapfr.html
# Title:  i.eb.evapfr - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\i.eb.evapfr.toml
# 1 tool_name: i.eb.evapfr
# Processing: 10 / 306, i.eb.hsebal01.coords
#     URL: https://grass.osgeo.org/grass84/manuals/i.eb.hsebal01.coords.html
# Failed to retrieve the page. Status code: 404
# error: cannot access local variable 'soup' where it is not associated with a value
# Processing: 11 / 306, i.eb.netrad
#     URL: https://grass.osgeo.org/grass84/manuals/i.eb.netrad.html
# Title:  i.eb.netrad - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\i.eb.netrad.toml
# 1 tool_name: i.eb.netrad
# Processing: 12 / 306, i.eb.soilheatflux
#     URL: https://grass.osgeo.org/grass84/manuals/i.eb.soilheatflux.html
# Title:  i.eb.soilheatflux - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\i.eb.soilheatflux.toml
# 1 tool_name: i.eb.soilheatflux
# Processing: 13 / 306, i.emissivity
#     URL: https://grass.osgeo.org/grass84/manuals/i.emissivity.html
# Title:  i.emissivity - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\i.emissivity.toml
# 1 tool_name: i.emissivity
# Processing: 14 / 306, i.evapo.mh
#     URL: https://grass.osgeo.org/grass84/manuals/i.evapo.mh.html
# Title:  i.evapo.mh - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\i.evapo.mh.toml
# 1 tool_name: i.evapo.mh
# Processing: 15 / 306, i.evapo.pm
#     URL: https://grass.osgeo.org/grass84/manuals/i.evapo.pm.html
# Title:  i.evapo.pm - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\i.evapo.pm.toml
# 1 tool_name: i.evapo.pm
# Processing: 16 / 306, i.evapo.pt
#     URL: https://grass.osgeo.org/grass84/manuals/i.evapo.pt.html
# Title:  i.evapo.pt - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\i.evapo.pt.toml
# 1 tool_name: i.evapo.pt
# Processing: 17 / 306, i.evapo.time
#     URL: https://grass.osgeo.org/grass84/manuals/i.evapo.time.html
# Title:  i.evapo.time - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\i.evapo.time.toml
# 1 tool_name: i.evapo.time
# Processing: 18 / 306, i.fft
#     URL: https://grass.osgeo.org/grass84/manuals/i.fft.html
# Title:  i.fft - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\i.fft.toml
# 1 tool_name: i.fft
# Processing: 19 / 306, i.gensig
#     URL: https://grass.osgeo.org/grass84/manuals/i.gensig.html
# Title:  i.gensig - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\i.gensig.toml
# 1 tool_name: i.gensig
# Processing: 20 / 306, i.gensigset
#     URL: https://grass.osgeo.org/grass84/manuals/i.gensigset.html
# Title:  i.gensigset - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\i.gensigset.toml
# 1 tool_name: i.gensigset
# Processing: 21 / 306, i.group
#     URL: https://grass.osgeo.org/grass84/manuals/i.group.html
# Title:  i.group - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\i.group.toml
# 1 tool_name: i.group
# Processing: 22 / 306, i.his.rgb
#     URL: https://grass.osgeo.org/grass84/manuals/i.his.rgb.html
# Title:  i.his.rgb - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\i.his.rgb.toml
# 1 tool_name: i.his.rgb
# Processing: 23 / 306, i.ifft
#     URL: https://grass.osgeo.org/grass84/manuals/i.ifft.html
# Title:  i.ifft - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\i.ifft.toml
# 1 tool_name: i.ifft
# Processing: 24 / 306, i.image.mosaic
#     URL: https://grass.osgeo.org/grass84/manuals/i.image.mosaic.html
# Title:  i.image.mosaic - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\i.image.mosaic.toml
# 1 tool_name: i.image.mosaic
# Processing: 25 / 306, i.in.spotvgt
#     URL: https://grass.osgeo.org/grass84/manuals/i.in.spotvgt.html
# Title:  i.in.spotvgt - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\i.in.spotvgt.toml
# 1 tool_name: i.in.spotvgt
# Processing: 26 / 306, i.landsat.acca
#     URL: https://grass.osgeo.org/grass84/manuals/i.landsat.acca.html
# Title:  i.landsat.acca - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\i.landsat.acca.toml
# 1 tool_name: i.landsat.acca
# Processing: 27 / 306, i.landsat.toar
#     URL: https://grass.osgeo.org/grass84/manuals/i.landsat.toar.html
# Title:  i.landsat.toar - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\i.landsat.toar.toml
# 1 tool_name: i.landsat.toar
# Processing: 28 / 306, i.maxlik
#     URL: https://grass.osgeo.org/grass84/manuals/i.maxlik.html
# Title:  i.maxlik - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\i.maxlik.toml
# 1 tool_name: i.maxlik
# Processing: 29 / 306, i.modis.qc
#     URL: https://grass.osgeo.org/grass84/manuals/i.modis.qc.html
# Title:  i.modis.qc - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\i.modis.qc.toml
# 1 tool_name: i.modis.qc
# Processing: 30 / 306, i.oif
#     URL: https://grass.osgeo.org/grass84/manuals/i.oif.html
# Title:  i.oif - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\i.oif.toml
# 1 tool_name: i.oif
# Processing: 31 / 306, i.pansharpen
#     URL: https://grass.osgeo.org/grass84/manuals/i.pansharpen.html
# Title:  i.pansharpen - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\i.pansharpen.toml
# 1 tool_name: i.pansharpen
# Processing: 32 / 306, i.pca
#     URL: https://grass.osgeo.org/grass84/manuals/i.pca.html
# Title:  i.pca - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\i.pca.toml
# 1 tool_name: i.pca
# Processing: 33 / 306, i.rgb.his
#     URL: https://grass.osgeo.org/grass84/manuals/i.rgb.his.html
# Title:  i.rgb.his - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\i.rgb.his.toml
# 1 tool_name: i.rgb.his
# Processing: 34 / 306, i.segment
#     URL: https://grass.osgeo.org/grass84/manuals/i.segment.html
# Title:  i.segment - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\i.segment.toml
# 1 tool_name: i.segment
# Processing: 35 / 306, i.smap
#     URL: https://grass.osgeo.org/grass84/manuals/i.smap.html
# Title:  i.smap - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\i.smap.toml
# 1 tool_name: i.smap
# Processing: 36 / 306, i.tasscap
#     URL: https://grass.osgeo.org/grass84/manuals/i.tasscap.html
# Title:  i.tasscap - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\i.tasscap.toml
# 1 tool_name: i.tasscap
# Processing: 37 / 306, i.topo.coor.ill
#     URL: https://grass.osgeo.org/grass84/manuals/i.topo.coor.ill.html
# Failed to retrieve the page. Status code: 404
# error: cannot access local variable 'soup' where it is not associated with a value
# Processing: 38 / 306, i.topo.corr
#     URL: https://grass.osgeo.org/grass84/manuals/i.topo.corr.html
# Title:  i.topo.corr - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\i.topo.corr.toml
# 1 tool_name: i.topo.corr
# Processing: 39 / 306, i.vi
#     URL: https://grass.osgeo.org/grass84/manuals/i.vi.html
# Title:  i.vi - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\i.vi.toml
# 1 tool_name: i.vi
# Processing: 40 / 306, i.zc
#     URL: https://grass.osgeo.org/grass84/manuals/i.zc.html
# Title:  i.zc - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\i.zc.toml
# 1 tool_name: i.zc
# Processing: 41 / 306, m.cogo
#     URL: https://grass.osgeo.org/grass84/manuals/m.cogo.html
# Title:  m.cogo - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\m.cogo.toml
# 1 tool_name: m.cogo
# Processing: 42 / 306, nviz
#     URL: https://grass.osgeo.org/grass84/manuals/nviz.html
# Failed to retrieve the page. Status code: 404
# error: cannot access local variable 'soup' where it is not associated with a value
# Processing: 43 / 306, r.basins.fill
#     URL: https://grass.osgeo.org/grass84/manuals/r.basins.fill.html
# Title:  r.basins.fill - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\r.basins.fill.toml
# 1 tool_name: r.basins.fill
# Processing: 44 / 306, r.blend.combine
#     URL: https://grass.osgeo.org/grass84/manuals/r.blend.combine.html
# Failed to retrieve the page. Status code: 404
# error: cannot access local variable 'soup' where it is not associated with a value
# Processing: 45 / 306, r.blend.rgb
#     URL: https://grass.osgeo.org/grass84/manuals/r.blend.rgb.html
# Failed to retrieve the page. Status code: 404
# error: cannot access local variable 'soup' where it is not associated with a value
# Processing: 46 / 306, r.buffer
#     URL: https://grass.osgeo.org/grass84/manuals/r.buffer.html
# Title:  r.buffer - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\r.buffer.toml
# 1 tool_name: r.buffer
# Processing: 47 / 306, r.buffer.lowmem
#     URL: https://grass.osgeo.org/grass84/manuals/r.buffer.lowmem.html
# Title:  r.buffer.lowmem - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\r.buffer.lowmem.toml
# 1 tool_name: r.buffer.lowmem
# Processing: 48 / 306, r.carve
#     URL: https://grass.osgeo.org/grass84/manuals/r.carve.html
# Title:  r.carve - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\r.carve.toml
# 1 tool_name: r.carve
# Processing: 49 / 306, r.category
#     URL: https://grass.osgeo.org/grass84/manuals/r.category.html
# Title:  r.category - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\r.category.toml
# 1 tool_name: r.category
# Processing: 50 / 306, r.category.out
#     URL: https://grass.osgeo.org/grass84/manuals/r.category.out.html
# Failed to retrieve the page. Status code: 404
# error: cannot access local variable 'soup' where it is not associated with a value
# Processing: 51 / 306, r.circle
#     URL: https://grass.osgeo.org/grass84/manuals/r.circle.html
# Title:  r.circle - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\r.circle.toml
# 1 tool_name: r.circle
# Processing: 52 / 306, r.clump
#     URL: https://grass.osgeo.org/grass84/manuals/r.clump.html
# Title:  r.clump - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\r.clump.toml
# 1 tool_name: r.clump
# Processing: 53 / 306, r.coin
#     URL: https://grass.osgeo.org/grass84/manuals/r.coin.html
# Title:  r.coin - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\r.coin.toml
# 1 tool_name: r.coin
# Processing: 54 / 306, r.colors
#     URL: https://grass.osgeo.org/grass84/manuals/r.colors.html
# Title:  r.colors - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\r.colors.toml
# 1 tool_name: r.colors
# Processing: 55 / 306, r.colors.out
#     URL: https://grass.osgeo.org/grass84/manuals/r.colors.out.html
# Title:  r.colors.out - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\r.colors.out.toml
# 1 tool_name: r.colors.out
# Processing: 56 / 306, r.colors.stddev
#     URL: https://grass.osgeo.org/grass84/manuals/r.colors.stddev.html
# Title:  r.colors.stddev - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\r.colors.stddev.toml
# 1 tool_name: r.colors.stddev
# Processing: 57 / 306, r.composite
#     URL: https://grass.osgeo.org/grass84/manuals/r.composite.html
# Title:  r.composite - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\r.composite.toml
# 1 tool_name: r.composite
# Processing: 58 / 306, r.contour
#     URL: https://grass.osgeo.org/grass84/manuals/r.contour.html
# Title:  r.contour - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\r.contour.toml
# 1 tool_name: r.contour
# Processing: 59 / 306, r.cost
#     URL: https://grass.osgeo.org/grass84/manuals/r.cost.html
# Title:  r.cost - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\r.cost.toml
# 1 tool_name: r.cost
# Processing: 60 / 306, r.covar
#     URL: https://grass.osgeo.org/grass84/manuals/r.covar.html
# Title:  r.covar - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\r.covar.toml
# 1 tool_name: r.covar
# Processing: 61 / 306, r.cross
#     URL: https://grass.osgeo.org/grass84/manuals/r.cross.html
# Title:  r.cross - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\r.cross.toml
# 1 tool_name: r.cross
# Processing: 62 / 306, r.describe
#     URL: https://grass.osgeo.org/grass84/manuals/r.describe.html
# Title:  r.describe - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\r.describe.toml
# 1 tool_name: r.describe
# Processing: 63 / 306, r.distance
#     URL: https://grass.osgeo.org/grass84/manuals/r.distance.html
# Title:  r.distance - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\r.distance.toml
# 1 tool_name: r.distance
# Processing: 64 / 306, r.drain
#     URL: https://grass.osgeo.org/grass84/manuals/r.drain.html
# Title:  r.drain - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\r.drain.toml
# 1 tool_name: r.drain
# Processing: 65 / 306, r.fill.dir
#     URL: https://grass.osgeo.org/grass84/manuals/r.fill.dir.html
# Title:  r.fill.dir - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\r.fill.dir.toml
# 1 tool_name: r.fill.dir
# Processing: 66 / 306, r.fill.stats
#     URL: https://grass.osgeo.org/grass84/manuals/r.fill.stats.html
# Title:  r.fill.stats - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\r.fill.stats.toml
# 1 tool_name: r.fill.stats
# Processing: 67 / 306, r.fillnulls
#     URL: https://grass.osgeo.org/grass84/manuals/r.fillnulls.html
# Title:  r.fillnulls - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\r.fillnulls.toml
# 1 tool_name: r.fillnulls
# Processing: 68 / 306, r.flow
#     URL: https://grass.osgeo.org/grass84/manuals/r.flow.html
# Title:  r.flow - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\r.flow.toml
# 1 tool_name: r.flow
# Processing: 69 / 306, r.geomorphon
#     URL: https://grass.osgeo.org/grass84/manuals/r.geomorphon.html
# Title:  r.geomorphon - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\r.geomorphon.toml
# 1 tool_name: r.geomorphon
# Processing: 70 / 306, r.grow
#     URL: https://grass.osgeo.org/grass84/manuals/r.grow.html
# Title:  r.grow - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\r.grow.toml
# 1 tool_name: r.grow
# Processing: 71 / 306, r.grow.distance
#     URL: https://grass.osgeo.org/grass84/manuals/r.grow.distance.html
# Title:  r.grow.distance - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\r.grow.distance.toml
# 1 tool_name: r.grow.distance
# Processing: 72 / 306, r.gwflow
#     URL: https://grass.osgeo.org/grass84/manuals/r.gwflow.html
# Title:  r.gwflow - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\r.gwflow.toml
# 1 tool_name: r.gwflow
# Processing: 73 / 306, r.his
#     URL: https://grass.osgeo.org/grass84/manuals/r.his.html
# Title:  r.his - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\r.his.toml
# 1 tool_name: r.his
# Processing: 74 / 306, r.horizon
#     URL: https://grass.osgeo.org/grass84/manuals/r.horizon.html
# Title:  r.horizon - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\r.horizon.toml
# 1 tool_name: r.horizon
# Processing: 75 / 306, r.horizon.height
#     URL: https://grass.osgeo.org/grass84/manuals/r.horizon.height.html
# Failed to retrieve the page. Status code: 404
# error: cannot access local variable 'soup' where it is not associated with a value
# Processing: 76 / 306, r.in.lidar
#     URL: https://grass.osgeo.org/grass84/manuals/r.in.lidar.html
# Failed to retrieve the page. Status code: 404
# error: cannot access local variable 'soup' where it is not associated with a value
# Processing: 77 / 306, r.in.lidar.info
#     URL: https://grass.osgeo.org/grass84/manuals/r.in.lidar.info.html
# Failed to retrieve the page. Status code: 404
# error: cannot access local variable 'soup' where it is not associated with a value
# Processing: 78 / 306, r.info
#     URL: https://grass.osgeo.org/grass84/manuals/r.info.html
# Title:  r.info - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\r.info.toml
# 1 tool_name: r.info
# Processing: 79 / 306, r.kappa
#     URL: https://grass.osgeo.org/grass84/manuals/r.kappa.html
# Title:  r.kappa - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\r.kappa.toml
# 1 tool_name: r.kappa
# Processing: 80 / 306, r.lake
#     URL: https://grass.osgeo.org/grass84/manuals/r.lake.html
# Title:  r.lake - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\r.lake.toml
# 1 tool_name: r.lake
# Processing: 81 / 306, r.latlong
#     URL: https://grass.osgeo.org/grass84/manuals/r.latlong.html
# Title:  r.latlong - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\r.latlong.toml
# 1 tool_name: r.latlong
# Processing: 82 / 306, r.li.cwed
#     URL: https://grass.osgeo.org/grass84/manuals/r.li.cwed.html
# Title:  r.li.cwed - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\r.li.cwed.toml
# 1 tool_name: r.li.cwed
# Processing: 83 / 306, r.li.cwed.ascii
#     URL: https://grass.osgeo.org/grass84/manuals/r.li.cwed.ascii.html
# Failed to retrieve the page. Status code: 404
# error: cannot access local variable 'soup' where it is not associated with a value
# Processing: 84 / 306, r.li.dominance
#     URL: https://grass.osgeo.org/grass84/manuals/r.li.dominance.html
# Title:  r.li.dominance - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\r.li.dominance.toml
# 1 tool_name: r.li.dominance
# Processing: 85 / 306, r.li.dominance.ascii
#     URL: https://grass.osgeo.org/grass84/manuals/r.li.dominance.ascii.html
# Failed to retrieve the page. Status code: 404
# error: cannot access local variable 'soup' where it is not associated with a value
# Processing: 86 / 306, r.li.edgedensity
#     URL: https://grass.osgeo.org/grass84/manuals/r.li.edgedensity.html
# Title:  r.li.edgedensity - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\r.li.edgedensity.toml
# 1 tool_name: r.li.edgedensity
# Processing: 87 / 306, r.li.edgedensity.ascii
#     URL: https://grass.osgeo.org/grass84/manuals/r.li.edgedensity.ascii.html
# Failed to retrieve the page. Status code: 404
# error: cannot access local variable 'soup' where it is not associated with a value
# Processing: 88 / 306, r.li.mpa
#     URL: https://grass.osgeo.org/grass84/manuals/r.li.mpa.html
# Title:  r.li.mpa - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\r.li.mpa.toml
# 1 tool_name: r.li.mpa
# Processing: 89 / 306, r.li.mpa.ascii
#     URL: https://grass.osgeo.org/grass84/manuals/r.li.mpa.ascii.html
# Failed to retrieve the page. Status code: 404
# error: cannot access local variable 'soup' where it is not associated with a value
# Processing: 90 / 306, r.li.mps
#     URL: https://grass.osgeo.org/grass84/manuals/r.li.mps.html
# Title:  r.li.mps - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\r.li.mps.toml
# 1 tool_name: r.li.mps
# Processing: 91 / 306, r.li.mps.ascii
#     URL: https://grass.osgeo.org/grass84/manuals/r.li.mps.ascii.html
# Failed to retrieve the page. Status code: 404
# error: cannot access local variable 'soup' where it is not associated with a value
# Processing: 92 / 306, r.li.padcv
#     URL: https://grass.osgeo.org/grass84/manuals/r.li.padcv.html
# Title:  r.li.padcv - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\r.li.padcv.toml
# 1 tool_name: r.li.padcv
# Processing: 93 / 306, r.li.padcv.ascii
#     URL: https://grass.osgeo.org/grass84/manuals/r.li.padcv.ascii.html
# Failed to retrieve the page. Status code: 404
# error: cannot access local variable 'soup' where it is not associated with a value
# Processing: 94 / 306, r.li.padrange
#     URL: https://grass.osgeo.org/grass84/manuals/r.li.padrange.html
# Title:  r.li.padrange - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\r.li.padrange.toml
# 1 tool_name: r.li.padrange
# Processing: 95 / 306, r.li.padrange.ascii
#     URL: https://grass.osgeo.org/grass84/manuals/r.li.padrange.ascii.html
# Failed to retrieve the page. Status code: 404
# error: cannot access local variable 'soup' where it is not associated with a value
# Processing: 96 / 306, r.li.padsd
#     URL: https://grass.osgeo.org/grass84/manuals/r.li.padsd.html
# Title:  r.li.padsd - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\r.li.padsd.toml
# 1 tool_name: r.li.padsd
# Processing: 97 / 306, r.li.padsd.ascii
#     URL: https://grass.osgeo.org/grass84/manuals/r.li.padsd.ascii.html
# Failed to retrieve the page. Status code: 404
# error: cannot access local variable 'soup' where it is not associated with a value
# Processing: 98 / 306, r.li.patchdensity
#     URL: https://grass.osgeo.org/grass84/manuals/r.li.patchdensity.html
# Title:  r.li.patchdensity - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\r.li.patchdensity.toml
# 1 tool_name: r.li.patchdensity
# Processing: 99 / 306, r.li.patchdensity.ascii
#     URL: https://grass.osgeo.org/grass84/manuals/r.li.patchdensity.ascii.html
# Failed to retrieve the page. Status code: 404
# error: cannot access local variable 'soup' where it is not associated with a value
# Processing: 100 / 306, r.li.patchnum
#     URL: https://grass.osgeo.org/grass84/manuals/r.li.patchnum.html
# Title:  r.li.patchnum - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\r.li.patchnum.toml
# 1 tool_name: r.li.patchnum
# Processing: 101 / 306, r.li.patchnum.ascii
#     URL: https://grass.osgeo.org/grass84/manuals/r.li.patchnum.ascii.html
# Failed to retrieve the page. Status code: 404
# error: cannot access local variable 'soup' where it is not associated with a value
# Processing: 102 / 306, r.li.pielou
#     URL: https://grass.osgeo.org/grass84/manuals/r.li.pielou.html
# Title:  r.li.pielou - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\r.li.pielou.toml
# 1 tool_name: r.li.pielou
# Processing: 103 / 306, r.li.pielou.ascii
#     URL: https://grass.osgeo.org/grass84/manuals/r.li.pielou.ascii.html
# Failed to retrieve the page. Status code: 404
# error: cannot access local variable 'soup' where it is not associated with a value
# Processing: 104 / 306, r.li.renyi
#     URL: https://grass.osgeo.org/grass84/manuals/r.li.renyi.html
# Title:  r.li.renyi - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\r.li.renyi.toml
# 1 tool_name: r.li.renyi
# Processing: 105 / 306, r.li.renyi.ascii
#     URL: https://grass.osgeo.org/grass84/manuals/r.li.renyi.ascii.html
# Failed to retrieve the page. Status code: 404
# error: cannot access local variable 'soup' where it is not associated with a value
# Processing: 106 / 306, r.li.richness
#     URL: https://grass.osgeo.org/grass84/manuals/r.li.richness.html
# Title:  r.li.richness - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\r.li.richness.toml
# 1 tool_name: r.li.richness
# Processing: 107 / 306, r.li.richness.ascii
#     URL: https://grass.osgeo.org/grass84/manuals/r.li.richness.ascii.html
# Failed to retrieve the page. Status code: 404
# error: cannot access local variable 'soup' where it is not associated with a value
# Processing: 108 / 306, r.li.shannon
#     URL: https://grass.osgeo.org/grass84/manuals/r.li.shannon.html
# Title:  r.li.shannon - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\r.li.shannon.toml
# 1 tool_name: r.li.shannon
# Processing: 109 / 306, r.li.shannon.ascii
#     URL: https://grass.osgeo.org/grass84/manuals/r.li.shannon.ascii.html
# Failed to retrieve the page. Status code: 404
# error: cannot access local variable 'soup' where it is not associated with a value
# Processing: 110 / 306, r.li.shape
#     URL: https://grass.osgeo.org/grass84/manuals/r.li.shape.html
# Title:  r.li.shape - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\r.li.shape.toml
# 1 tool_name: r.li.shape
# Processing: 111 / 306, r.li.shape.ascii
#     URL: https://grass.osgeo.org/grass84/manuals/r.li.shape.ascii.html
# Failed to retrieve the page. Status code: 404
# error: cannot access local variable 'soup' where it is not associated with a value
# Processing: 112 / 306, r.li.simpson
#     URL: https://grass.osgeo.org/grass84/manuals/r.li.simpson.html
# Title:  r.li.simpson - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\r.li.simpson.toml
# 1 tool_name: r.li.simpson
# Processing: 113 / 306, r.li.simpson.ascii
#     URL: https://grass.osgeo.org/grass84/manuals/r.li.simpson.ascii.html
# Failed to retrieve the page. Status code: 404
# error: cannot access local variable 'soup' where it is not associated with a value
# Processing: 114 / 306, r.mapcalc.simple
#     URL: https://grass.osgeo.org/grass84/manuals/r.mapcalc.simple.html
# Title:  r.mapcalc.simple - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\r.mapcalc.simple.toml
# 1 tool_name: r.mapcalc.simple
# Processing: 115 / 306, r.mask.rast
#     URL: https://grass.osgeo.org/grass84/manuals/r.mask.rast.html
# Failed to retrieve the page. Status code: 404
# error: cannot access local variable 'soup' where it is not associated with a value
# Processing: 116 / 306, r.mask.vect
#     URL: https://grass.osgeo.org/grass84/manuals/r.mask.vect.html
# Failed to retrieve the page. Status code: 404
# error: cannot access local variable 'soup' where it is not associated with a value
# Processing: 117 / 306, r.mfilter
#     URL: https://grass.osgeo.org/grass84/manuals/r.mfilter.html
# Title:  r.mfilter - GRASS GIS manual
# Error in processing 'div' tag:  r.mfilter 'class'
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\r.mfilter.toml
# 1 tool_name: r.mfilter
# Processing: 118 / 306, r.mode
#     URL: https://grass.osgeo.org/grass84/manuals/r.mode.html
# Title:  r.mode - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\r.mode.toml
# 1 tool_name: r.mode
# Processing: 119 / 306, r.neighbors
#     URL: https://grass.osgeo.org/grass84/manuals/r.neighbors.html
# Title:  r.neighbors - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\r.neighbors.toml
# 1 tool_name: r.neighbors
# Processing: 120 / 306, r.null
#     URL: https://grass.osgeo.org/grass84/manuals/r.null.html
# Title:  r.null - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\r.null.toml
# 1 tool_name: r.null
# Processing: 121 / 306, r.out.ascii
#     URL: https://grass.osgeo.org/grass84/manuals/r.out.ascii.html
# Title:  r.out.ascii - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\r.out.ascii.toml
# 1 tool_name: r.out.ascii
# Processing: 122 / 306, r.out.gridatb
#     URL: https://grass.osgeo.org/grass84/manuals/r.out.gridatb.html
# Title:  r.out.gridatb - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\r.out.gridatb.toml
# 1 tool_name: r.out.gridatb
# Processing: 123 / 306, r.out.mat
#     URL: https://grass.osgeo.org/grass84/manuals/r.out.mat.html
# Title:  r.out.mat - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\r.out.mat.toml
# 1 tool_name: r.out.mat
# Processing: 124 / 306, r.out.mpeg
#     URL: https://grass.osgeo.org/grass84/manuals/r.out.mpeg.html
# Title:  r.out.mpeg - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\r.out.mpeg.toml
# 1 tool_name: r.out.mpeg
# Processing: 125 / 306, r.out.png
#     URL: https://grass.osgeo.org/grass84/manuals/r.out.png.html
# Title:  r.out.png - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\r.out.png.toml
# 1 tool_name: r.out.png
# Processing: 126 / 306, r.out.pov
#     URL: https://grass.osgeo.org/grass84/manuals/r.out.pov.html
# Title:  r.out.pov - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\r.out.pov.toml
# 1 tool_name: r.out.pov
# Processing: 127 / 306, r.out.ppm
#     URL: https://grass.osgeo.org/grass84/manuals/r.out.ppm.html
# Title:  r.out.ppm - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\r.out.ppm.toml
# 1 tool_name: r.out.ppm
# Processing: 128 / 306, r.out.ppm3
#     URL: https://grass.osgeo.org/grass84/manuals/r.out.ppm3.html
# Title:  r.out.ppm3 - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\r.out.ppm3.toml
# 1 tool_name: r.out.ppm3
# Processing: 129 / 306, r.out.vrml
#     URL: https://grass.osgeo.org/grass84/manuals/r.out.vrml.html
# Title:  r.out.vrml - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\r.out.vrml.toml
# 1 tool_name: r.out.vrml
# Processing: 130 / 306, r.out.vtk
#     URL: https://grass.osgeo.org/grass84/manuals/r.out.vtk.html
# Title:  r.out.vtk - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\r.out.vtk.toml
# 1 tool_name: r.out.vtk
# Processing: 131 / 306, r.out.xyz
#     URL: https://grass.osgeo.org/grass84/manuals/r.out.xyz.html
# Title:  r.out.xyz - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\r.out.xyz.toml
# 1 tool_name: r.out.xyz
# Processing: 132 / 306, r.param.scale
#     URL: https://grass.osgeo.org/grass84/manuals/r.param.scale.html
# Title:  r.param.scale - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\r.param.scale.toml
# 1 tool_name: r.param.scale
# Processing: 133 / 306, r.patch
#     URL: https://grass.osgeo.org/grass84/manuals/r.patch.html
# Title:  r.patch - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\r.patch.toml
# 1 tool_name: r.patch
# Processing: 134 / 306, r.path
#     URL: https://grass.osgeo.org/grass84/manuals/r.path.html
# Title:  r.path - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\r.path.toml
# 1 tool_name: r.path
# Processing: 135 / 306, r.path.coordinate.txt
#     URL: https://grass.osgeo.org/grass84/manuals/r.path.coordinate.txt.html
# Failed to retrieve the page. Status code: 404
# error: cannot access local variable 'soup' where it is not associated with a value
# Processing: 136 / 306, r.plane
#     URL: https://grass.osgeo.org/grass84/manuals/r.plane.html
# Title:  r.plane - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\r.plane.toml
# 1 tool_name: r.plane
# Processing: 137 / 306, r.profile
#     URL: https://grass.osgeo.org/grass84/manuals/r.profile.html
# Title:  r.profile - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\r.profile.toml
# 1 tool_name: r.profile
# Processing: 138 / 306, r.proj
#     URL: https://grass.osgeo.org/grass84/manuals/r.proj.html
# Title:  r.proj - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\r.proj.toml
# 1 tool_name: r.proj
# Processing: 139 / 306, r.quant
#     URL: https://grass.osgeo.org/grass84/manuals/r.quant.html
# Title:  r.quant - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\r.quant.toml
# 1 tool_name: r.quant
# Processing: 140 / 306, r.quantile
#     URL: https://grass.osgeo.org/grass84/manuals/r.quantile.html
# Title:  r.quantile - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\r.quantile.toml
# 1 tool_name: r.quantile
# Processing: 141 / 306, r.quantile.plain
#     URL: https://grass.osgeo.org/grass84/manuals/r.quantile.plain.html
# Failed to retrieve the page. Status code: 404
# error: cannot access local variable 'soup' where it is not associated with a value
# Processing: 142 / 306, r.random
#     URL: https://grass.osgeo.org/grass84/manuals/r.random.html
# Title:  r.random - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\r.random.toml
# 1 tool_name: r.random
# Processing: 143 / 306, r.random.cells
#     URL: https://grass.osgeo.org/grass84/manuals/r.random.cells.html
# Title:  r.random.cells - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\r.random.cells.toml
# 1 tool_name: r.random.cells
# Processing: 144 / 306, r.random.surface
#     URL: https://grass.osgeo.org/grass84/manuals/r.random.surface.html
# Title:  r.random.surface - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\r.random.surface.toml
# 1 tool_name: r.random.surface
# Processing: 145 / 306, r.reclass
#     URL: https://grass.osgeo.org/grass84/manuals/r.reclass.html
# Title:  r.reclass - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\r.reclass.toml
# 1 tool_name: r.reclass
# Processing: 146 / 306, r.reclass.area
#     URL: https://grass.osgeo.org/grass84/manuals/r.reclass.area.html
# Title:  r.reclass.area - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\r.reclass.area.toml
# 1 tool_name: r.reclass.area
# Processing: 147 / 306, r.recode
#     URL: https://grass.osgeo.org/grass84/manuals/r.recode.html
# Title:  r.recode - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\r.recode.toml
# 1 tool_name: r.recode
# Processing: 148 / 306, r.regression.line
#     URL: https://grass.osgeo.org/grass84/manuals/r.regression.line.html
# Title:  r.regression.line - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\r.regression.line.toml
# 1 tool_name: r.regression.line
# Processing: 149 / 306, r.regression.multi
#     URL: https://grass.osgeo.org/grass84/manuals/r.regression.multi.html
# Title:  r.regression.multi - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\r.regression.multi.toml
# 1 tool_name: r.regression.multi
# Processing: 150 / 306, r.relief
#     URL: https://grass.osgeo.org/grass84/manuals/r.relief.html
# Title:  r.relief - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\r.relief.toml
# 1 tool_name: r.relief
# Processing: 151 / 306, r.relief.scaling
#     URL: https://grass.osgeo.org/grass84/manuals/r.relief.scaling.html
# Failed to retrieve the page. Status code: 404
# error: cannot access local variable 'soup' where it is not associated with a value
# Processing: 152 / 306, r.report
#     URL: https://grass.osgeo.org/grass84/manuals/r.report.html
# Title:  r.report - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\r.report.toml
# 1 tool_name: r.report
# Processing: 153 / 306, r.resamp.bspline
#     URL: https://grass.osgeo.org/grass84/manuals/r.resamp.bspline.html
# Title:  r.resamp.bspline - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\r.resamp.bspline.toml
# 1 tool_name: r.resamp.bspline
# Processing: 154 / 306, r.resamp.filter
#     URL: https://grass.osgeo.org/grass84/manuals/r.resamp.filter.html
# Title:  r.resamp.filter - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\r.resamp.filter.toml
# 1 tool_name: r.resamp.filter
# Processing: 155 / 306, r.resamp.interp
#     URL: https://grass.osgeo.org/grass84/manuals/r.resamp.interp.html
# Title:  r.resamp.interp - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\r.resamp.interp.toml
# 1 tool_name: r.resamp.interp
# Processing: 156 / 306, r.resamp.rst
#     URL: https://grass.osgeo.org/grass84/manuals/r.resamp.rst.html
# Title:  r.resamp.rst - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\r.resamp.rst.toml
# 1 tool_name: r.resamp.rst
# Processing: 157 / 306, r.resamp.stats
#     URL: https://grass.osgeo.org/grass84/manuals/r.resamp.stats.html
# Title:  r.resamp.stats - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\r.resamp.stats.toml
# 1 tool_name: r.resamp.stats
# Processing: 158 / 306, r.resample
#     URL: https://grass.osgeo.org/grass84/manuals/r.resample.html
# Title:  r.resample - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\r.resample.toml
# 1 tool_name: r.resample
# Processing: 159 / 306, r.rescale
#     URL: https://grass.osgeo.org/grass84/manuals/r.rescale.html
# Title:  r.rescale - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\r.rescale.toml
# 1 tool_name: r.rescale
# Processing: 160 / 306, r.rescale.eq
#     URL: https://grass.osgeo.org/grass84/manuals/r.rescale.eq.html
# Title:  r.rescale.eq - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\r.rescale.eq.toml
# 1 tool_name: r.rescale.eq
# Processing: 161 / 306, r.rgb
#     URL: https://grass.osgeo.org/grass84/manuals/r.rgb.html
# Title:  r.rgb - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\r.rgb.toml
# 1 tool_name: r.rgb
# Processing: 162 / 306, r.ros
#     URL: https://grass.osgeo.org/grass84/manuals/r.ros.html
# Title:  r.ros - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\r.ros.toml
# 1 tool_name: r.ros
# Processing: 163 / 306, r.series
#     URL: https://grass.osgeo.org/grass84/manuals/r.series.html
# Title:  r.series - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\r.series.toml
# 1 tool_name: r.series
# Processing: 164 / 306, r.series.accumulate
#     URL: https://grass.osgeo.org/grass84/manuals/r.series.accumulate.html
# Title:  r.series.accumulate - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\r.series.accumulate.toml
# 1 tool_name: r.series.accumulate
# Processing: 165 / 306, r.series.interp
#     URL: https://grass.osgeo.org/grass84/manuals/r.series.interp.html
# Title:  r.series.interp - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\r.series.interp.toml
# 1 tool_name: r.series.interp
# Processing: 166 / 306, r.shade
#     URL: https://grass.osgeo.org/grass84/manuals/r.shade.html
# Title:  r.shade - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\r.shade.toml
# 1 tool_name: r.shade
# Processing: 167 / 306, r.sim.sediment
#     URL: https://grass.osgeo.org/grass84/manuals/r.sim.sediment.html
# Title:  r.sim.sediment - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\r.sim.sediment.toml
# 1 tool_name: r.sim.sediment
# Processing: 168 / 306, r.sim.water
#     URL: https://grass.osgeo.org/grass84/manuals/r.sim.water.html
# Title:  r.sim.water - GRASS GIS manual
# Error in processing 'div' tag:  r.sim.water 'class'
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\r.sim.water.toml
# 1 tool_name: r.sim.water
# Processing: 169 / 306, r.slope.aspect
#     URL: https://grass.osgeo.org/grass84/manuals/r.slope.aspect.html
# Title:  r.slope.aspect - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\r.slope.aspect.toml
# 1 tool_name: r.slope.aspect
# Processing: 170 / 306, r.solute.transport
# ...
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\v.net.bridge.toml
# 1 tool_name: v.net.bridge
# Processing: 251 / 306, v.net.centrality
#     URL: https://grass.osgeo.org/grass84/manuals/v.net.centrality.html
# Title:  v.net.centrality - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\v.net.centrality.toml
# 1 tool_name: v.net.centrality
# Processing: 252 / 306, v.net.components
#     URL: https://grass.osgeo.org/grass84/manuals/v.net.components.html
# Title:  v.net.components - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\v.net.components.toml
# 1 tool_name: v.net.components
# Processing: 253 / 306, v.net.connectivity
#     URL: https://grass.osgeo.org/grass84/manuals/v.net.connectivity.html
# Title:  v.net.connectivity - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\v.net.connectivity.toml
# 1 tool_name: v.net.connectivity
# Processing: 254 / 306, v.net.distance
#     URL: https://grass.osgeo.org/grass84/manuals/v.net.distance.html
# Title:  v.net.distance - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\v.net.distance.toml
# 1 tool_name: v.net.distance
# Processing: 255 / 306, v.net.flow
#     URL: https://grass.osgeo.org/grass84/manuals/v.net.flow.html
# Title:  v.net.flow - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\v.net.flow.toml
# 1 tool_name: v.net.flow
# Processing: 256 / 306, v.net.iso
#     URL: https://grass.osgeo.org/grass84/manuals/v.net.iso.html
# Title:  v.net.iso - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\v.net.iso.toml
# 1 tool_name: v.net.iso
# Processing: 257 / 306, v.net.nreport
#     URL: https://grass.osgeo.org/grass84/manuals/v.net.nreport.html
# Failed to retrieve the page. Status code: 404
# error: cannot access local variable 'soup' where it is not associated with a value
# Processing: 258 / 306, v.net.path
#     URL: https://grass.osgeo.org/grass84/manuals/v.net.path.html
# Title:  v.net.path - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\v.net.path.toml
# 1 tool_name: v.net.path
# Processing: 259 / 306, v.net.report
#     URL: https://grass.osgeo.org/grass84/manuals/v.net.report.html
# Failed to retrieve the page. Status code: 404
# error: cannot access local variable 'soup' where it is not associated with a value
# Processing: 260 / 306, v.net.salesman
#     URL: https://grass.osgeo.org/grass84/manuals/v.net.salesman.html
# Title:  v.net.salesman - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\v.net.salesman.toml
# 1 tool_name: v.net.salesman
# Processing: 261 / 306, v.net.spanningtree
#     URL: https://grass.osgeo.org/grass84/manuals/v.net.spanningtree.html
# Title:  v.net.spanningtree - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\v.net.spanningtree.toml
# 1 tool_name: v.net.spanningtree
# Processing: 262 / 306, v.net.steiner
#     URL: https://grass.osgeo.org/grass84/manuals/v.net.steiner.html
# Title:  v.net.steiner - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\v.net.steiner.toml
# 1 tool_name: v.net.steiner
# Processing: 263 / 306, v.net.timetable
#     URL: https://grass.osgeo.org/grass84/manuals/v.net.timetable.html
# Title:  v.net.timetable - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\v.net.timetable.toml
# 1 tool_name: v.net.timetable
# Processing: 264 / 306, v.net.visibility
#     URL: https://grass.osgeo.org/grass84/manuals/v.net.visibility.html
# Title:  v.net.visibility - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\v.net.visibility.toml
# 1 tool_name: v.net.visibility
# Processing: 265 / 306, v.normal
#     URL: https://grass.osgeo.org/grass84/manuals/v.normal.html
# Title:  v.normal - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\v.normal.toml
# 1 tool_name: v.normal
# Processing: 266 / 306, v.out.ascii
#     URL: https://grass.osgeo.org/grass84/manuals/v.out.ascii.html
# Title:  v.out.ascii - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\v.out.ascii.toml
# 1 tool_name: v.out.ascii
# Processing: 267 / 306, v.out.dxf
#     URL: https://grass.osgeo.org/grass84/manuals/v.out.dxf.html
# Title:  v.out.dxf - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\v.out.dxf.toml
# 1 tool_name: v.out.dxf
# Processing: 268 / 306, v.out.postgis
#     URL: https://grass.osgeo.org/grass84/manuals/v.out.postgis.html
# Title:  v.out.postgis - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\v.out.postgis.toml
# 1 tool_name: v.out.postgis
# Processing: 269 / 306, v.out.pov
#     URL: https://grass.osgeo.org/grass84/manuals/v.out.pov.html
# Title:  v.out.pov - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\v.out.pov.toml
# 1 tool_name: v.out.pov
# Processing: 270 / 306, v.out.svg
#     URL: https://grass.osgeo.org/grass84/manuals/v.out.svg.html
# Title:  v.out.svg - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\v.out.svg.toml
# 1 tool_name: v.out.svg
# Processing: 271 / 306, v.out.vtk
#     URL: https://grass.osgeo.org/grass84/manuals/v.out.vtk.html
# Title:  v.out.vtk - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\v.out.vtk.toml
# 1 tool_name: v.out.vtk
# Processing: 272 / 306, v.outlier
#     URL: https://grass.osgeo.org/grass84/manuals/v.outlier.html
# Title:  v.outlier - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\v.outlier.toml
# 1 tool_name: v.outlier
# Processing: 273 / 306, v.overlay
#     URL: https://grass.osgeo.org/grass84/manuals/v.overlay.html
# Title:  v.overlay - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\v.overlay.toml
# 1 tool_name: v.overlay
# Processing: 274 / 306, v.pack
#     URL: https://grass.osgeo.org/grass84/manuals/v.pack.html
# Title:  v.pack - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\v.pack.toml
# 1 tool_name: v.pack
# Processing: 275 / 306, v.parallel
#     URL: https://grass.osgeo.org/grass84/manuals/v.parallel.html
# Title:  v.parallel - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\v.parallel.toml
# 1 tool_name: v.parallel
# Processing: 276 / 306, v.patch
#     URL: https://grass.osgeo.org/grass84/manuals/v.patch.html
# Title:  v.patch - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\v.patch.toml
# 1 tool_name: v.patch
# Processing: 277 / 306, v.perturb
#     URL: https://grass.osgeo.org/grass84/manuals/v.perturb.html
# Title:  v.perturb - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\v.perturb.toml
# 1 tool_name: v.perturb
# Processing: 278 / 306, v.proj
#     URL: https://grass.osgeo.org/grass84/manuals/v.proj.html
# Title:  v.proj - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\v.proj.toml
# 1 tool_name: v.proj
# Processing: 279 / 306, v.qcount
#     URL: https://grass.osgeo.org/grass84/manuals/v.qcount.html
# Title:  v.qcount - GRASS GIS manual
# Error in processing 'div' tag:  v.qcount 'class'
# Error in processing 'div' tag:  v.qcount 'class'
# Error in processing 'div' tag:  v.qcount 'class'
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\v.qcount.toml
# 1 tool_name: v.qcount
# Processing: 280 / 306, v.random
#     URL: https://grass.osgeo.org/grass84/manuals/v.random.html
# Title:  v.random - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\v.random.toml
# 1 tool_name: v.random
# Processing: 281 / 306, v.rast.stats
#     URL: https://grass.osgeo.org/grass84/manuals/v.rast.stats.html
# Title:  v.rast.stats - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\v.rast.stats.toml
# 1 tool_name: v.rast.stats
# Processing: 282 / 306, v.reclass
#     URL: https://grass.osgeo.org/grass84/manuals/v.reclass.html
# Title:  v.reclass - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\v.reclass.toml
# 1 tool_name: v.reclass
# Processing: 283 / 306, v.rectify
#     URL: https://grass.osgeo.org/grass84/manuals/v.rectify.html
# Title:  v.rectify - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\v.rectify.toml
# 1 tool_name: v.rectify
# Processing: 284 / 306, v.report
#     URL: https://grass.osgeo.org/grass84/manuals/v.report.html
# Title:  v.report - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\v.report.toml
# 1 tool_name: v.report
# Processing: 285 / 306, v.sample
#     URL: https://grass.osgeo.org/grass84/manuals/v.sample.html
# Title:  v.sample - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\v.sample.toml
# 1 tool_name: v.sample
# Processing: 286 / 306, v.segment
#     URL: https://grass.osgeo.org/grass84/manuals/v.segment.html
# Title:  v.segment - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\v.segment.toml
# 1 tool_name: v.segment
# Processing: 287 / 306, v.select
#     URL: https://grass.osgeo.org/grass84/manuals/v.select.html
# Title:  v.select - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\v.select.toml
# 1 tool_name: v.select
# Processing: 288 / 306, v.split
#     URL: https://grass.osgeo.org/grass84/manuals/v.split.html
# Title:  v.split - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\v.split.toml
# 1 tool_name: v.split
# Processing: 289 / 306, v.surf.bspline
#     URL: https://grass.osgeo.org/grass84/manuals/v.surf.bspline.html
# Title:  v.surf.bspline - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\v.surf.bspline.toml
# 1 tool_name: v.surf.bspline
# Processing: 290 / 306, v.surf.idw
#     URL: https://grass.osgeo.org/grass84/manuals/v.surf.idw.html
# Title:  v.surf.idw - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\v.surf.idw.toml
# 1 tool_name: v.surf.idw
# Processing: 291 / 306, v.surf.rst
#     URL: https://grass.osgeo.org/grass84/manuals/v.surf.rst.html
# Title:  v.surf.rst - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\v.surf.rst.toml
# 1 tool_name: v.surf.rst
# Processing: 292 / 306, v.surf.rst.cvdev
#     URL: https://grass.osgeo.org/grass84/manuals/v.surf.rst.cvdev.html
# Failed to retrieve the page. Status code: 404
# error: cannot access local variable 'soup' where it is not associated with a value
# Processing: 293 / 306, v.to.3d
#     URL: https://grass.osgeo.org/grass84/manuals/v.to.3d.html
# Title:  v.to.3d - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\v.to.3d.toml
# 1 tool_name: v.to.3d
# Processing: 294 / 306, v.to.lines
#     URL: https://grass.osgeo.org/grass84/manuals/v.to.lines.html
# Title:  v.to.lines - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\v.to.lines.toml
# 1 tool_name: v.to.lines
# Processing: 295 / 306, v.to.points
#     URL: https://grass.osgeo.org/grass84/manuals/v.to.points.html
# Title:  v.to.points - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\v.to.points.toml
# 1 tool_name: v.to.points
# Processing: 296 / 306, v.to.rast
#     URL: https://grass.osgeo.org/grass84/manuals/v.to.rast.html
# Title:  v.to.rast - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\v.to.rast.toml
# 1 tool_name: v.to.rast
# Processing: 297 / 306, v.transform
#     URL: https://grass.osgeo.org/grass84/manuals/v.transform.html
# Title:  v.transform - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\v.transform.toml
# 1 tool_name: v.transform
# Processing: 298 / 306, v.type
#     URL: https://grass.osgeo.org/grass84/manuals/v.type.html
# Title:  v.type - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\v.type.toml
# 1 tool_name: v.type
# Processing: 299 / 306, v.univar
#     URL: https://grass.osgeo.org/grass84/manuals/v.univar.html
# Title:  v.univar - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\v.univar.toml
# 1 tool_name: v.univar
# Processing: 300 / 306, v.vect.stats
#     URL: https://grass.osgeo.org/grass84/manuals/v.vect.stats.html
# Title:  v.vect.stats - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\v.vect.stats.toml
# 1 tool_name: v.vect.stats
# Processing: 301 / 306, v.voronoi
#     URL: https://grass.osgeo.org/grass84/manuals/v.voronoi.html
# Title:  v.voronoi - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\v.voronoi.toml
# 1 tool_name: v.voronoi
# Processing: 302 / 306, v.voronoi.skeleton
#     URL: https://grass.osgeo.org/grass84/manuals/v.voronoi.skeleton.html
# Failed to retrieve the page. Status code: 404
# error: cannot access local variable 'soup' where it is not associated with a value
# Processing: 303 / 306, v.what.rast
#     URL: https://grass.osgeo.org/grass84/manuals/v.what.rast.html
# Title:  v.what.rast - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\v.what.rast.toml
# 1 tool_name: v.what.rast
# Processing: 304 / 306, v.what.vect
#     URL: https://grass.osgeo.org/grass84/manuals/v.what.vect.html
# Title:  v.what.vect - GRASS GIS manual
# Saved at: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\GRASS_toml\v.what.vect.toml
# 1 tool_name: v.what.vect

# %%
for idx, url in enumerate(urls):
    print(f"Processing: {idx + 1} / {len(urls)}",  url)
    
    soup = get_response(url)
    sections = get_sections(soup)
    
    count = 0

    for section in sections[2:]:
        try:
            tool_info = extract_tool_info(section)    
            tool_name = tool_info['algorithm_id'].replace(":", "_")

            fname = os.path.join(save_dir, f"{tool_name}.toml")
            toml_str = make_TOML_file(tool_info, fname)
            # print("fname:", fname)
            count += 1

            print(f"{count} tool_name:", tool_name)

        except Exception as e:

            print("error:", e)
            pass
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 for idx, url in enumerate(urls):
#       2     print(f"Processing: {idx + 1} / {len(urls)}",  url)
#       4     soup = get_response(url)
#
# NameError: name 'urls' is not defined

# %% [markdown]
# # QGIS help page crawler

# %% [markdown]
# ## How to use?
# 1. Update the `url` variable using the links in [https://docs.qgis.org/3.34/en/docs/user_manual/processing_algs/index.html](https://docs.qgis.org/3.34/en/docs/user_manual/processing_algs/index.html), e.g., [https://docs.qgis.org/3.34/en/docs/user_manual/processing_algs/qgis/rasteranalysis.html](https://docs.qgis.org/3.34/en/docs/user_manual/processing_algs/qgis/rasteranalysis.html).
# 2. Run the program.
#
# **Please check the results manually to ensure they are correct!**

# %%
# ! pip install html5lib

# %%
import toml
import os
import re 
import io
import requests

# %%
##### These urls were processed.
# url = "https://docs.qgis.org/3.34/en/docs/user_manual/processing_algs/qgis/rasteranalysis.html"
# there are 156 sections, and 33 sections have h2 tag, while 31 tool sections.

# url = "https://docs.qgis.org/3.34/en/docs/user_manual/processing_algs/qgis/interpolation.html"
# url = "https://docs.qgis.org/3.34/en/docs/user_manual/processing_algs/qgis/vectoranalysis.html"
# url = "https://docs.qgis.org/3.34/en/docs/user_manual/processing_algs/qgis/vectorgeneral.html"
# url = "https://docs.qgis.org/3.34/en/docs/user_manual/processing_algs/qgis/vectorgeometry.html"
# url = "https://docs.qgis.org/3.34/en/docs/user_manual/processing_algs/gdal/rasteranalysis.html"
# url = "https://docs.qgis.org/3.34/en/docs/user_manual/processing_algs/qgis/plots.html"
# url = "https://docs.qgis.org/3.34/en/docs/user_manual/processing_algs/qgis/rasterterrainanalysis.html"


url = "https://docs.qgis.org/3.34/en/docs/user_manual/processing_algs/qgis/vectoroverlay.html"

def get_response(url):
    response = requests.get(url)

    # Check if the request was successful
    if response.status_code == 200:
        html_content = response.content
        # Parse the HTML content using BeautifulSoup
        soup = BeautifulSoup(html_content, 'html5lib')
        # soup = BeautifulSoup(html_content, 'html.parser')

        # Now you can work with 'soup' to extract the relevant sections
        # Example: printing the title of the page
        print("Title: ", soup.title.get_text())

    else:
        print(f"Failed to retrieve the page. Status code: {response.status_code}")
        
    return soup

soup = get_response(url)

# %%
urls[-1]

# %%
raw_sections = soup.find_all('section')
len(raw_sections)

# %%
# for idx, section in enumerate(sections):
    # print(idx)
    # print(section)

# %%
def get_sections(soup):
    raw_sections = soup.find_all('section')
    len(raw_sections)
    cnt = 0
    sections = []
    for idx, section in enumerate(raw_sections):

        section_id = section.get('id')  # Extract the section ID
        tag = section.find('h2')  # Try to find an <h3> tag in the section
        # print(tag)
        if tag:
            cnt += 1
            print(idx, cnt, f"Section with ID '{section_id}' contains an <h3> tag: '{tag.get_text()}'")
            # cnt += 1
            sections.append(section)
        else:
            # print(idx, f"Section with ID '{section_id}' does not contain an <h3> tag.")
            pass
    # len(sections)  
    return sections

sections = get_sections(soup)

# %%
def get_section_by_heading(section, level, heading):        
    tags = section.find_all(level)
    for tag in tags:
        if heading in tag.get_text():
            section_tag = tag.find_parent('section')
            # print(section_tag.prettify())  # Print the entire section for visualization
            return section_tag
    return None
    
def extract_table(section):
    # print("section:", section)
    table_data = []
    tables = section.find_all('table')
    # print("table:", table)
    for table in tables:
        if table:
            headers = [th.get_text(strip=True) for th in table.find_all('th')]
            rows = table.find_all('tr')[1:]  # Skip header row
            for row in rows:
                cols = row.find_all('td')
                # row_data = {headers[i]: cols[i].get_text(strip=True) for i in range(len(headers))}
                row_data = {headers[i]: cols[i].get_text(separator=' ', strip=True) for i in range(len(headers))}
                table_data.append(row_data)
    return table_data
    
# Helper function to normalize whitespace in a string
def normalize_whitespace(text):
    # Replace multiple spaces and newlines with a single space
    return re.sub(r'\s+', ' ', text).strip()
    
# Function to extract paragraphs before a section with a specific id and ensure spaces around <a> and <code> elements
def extract_paragraphs_before(section, stop_section_id):
    paragraphs = []
    
    for element in section.find_all(['p', 'h3'], recursive=False):
        # Stop if we encounter the sub-section (like "Parameters")
        if element.name == 'h3' and stop_section_id in element.get('id', ''):
            break
        if element.name == 'p':
            # Rebuild the paragraph's text, ensuring spaces around <a> and <code> tags
            paragraph_text = []
            for content in element.children:
                
                if content.name in ['a', 'code']:
                    paragraph_text.append(f" {content.get_text(strip=True)} ")
                    # print(content)
                else:
                    paragraph_text.append(content if isinstance(content, str) else content.get_text(strip=True))
                    # print(paragraph_text[-1])
            
            paragraphs.append(normalize_whitespace(''.join(paragraph_text)))
    
    return paragraphs
    
def make_parameters_for_TOML(tool_info):
    lines = []
    # for parameter in tool_info['basic_parameters']:
    #     line = f"{parameter['Name']}: {parameter['Description'].replace('\n', '')}. Type: {parameter['Type']}"
    #     lines.append(line)
        
    # for parameter in tool_info['advanced_parameters']:
    #     line = f"{parameter['Name']}: {parameter['Description'].replace('\n', '')}. Type: {parameter['Type']}"
    #     lines.append(line)

    for parameter in tool_info['parameters']:
        name = parameter['Name']
        label = parameter['Label'].replace('\n', '')
        description = parameter['Description'].replace('\n', '')
        param_type = parameter['Type']

        line = f"{name}: {label}. {description}. Type: {param_type}"
        lines.append(line)
    
    para_str = "\n".join(lines)
    return para_str

def make_outputs_for_TOML(tool_info):
    lines = []
    for output in tool_info['outputs']:
        try:
            name = output['Name']
            label = output['Label'].replace('\n', '')
            description = output['Description'].replace('\n', '')
            output_type = output['Type']

            line = f"{name}: {label}. {description}. Type: {output_type}"
            lines.append(line)
        except Exception as e:
            print("Error in make_outputs_for_TOML():", e)
    
    para_str = "\n".join(lines)
    return para_str
def make_TOML_file(tool_info, fname):
    tool_toml = {}
    tool_toml['tool_ID'] = tool_info['algorithm_id']
    tool_toml['tool_name'] = tool_info['tool_name']    
    tool_toml['brief_description'] = tool_info['brief_description']
    tool_toml['full_description'] = '\n'.join(tool_info['paragraphs'])
    tool_toml['parameters'] = make_parameters_for_TOML(tool_info)
    tool_toml['outputs'] = make_outputs_for_TOML(tool_info)
    tool_toml['code_example'] = ""
    with open(fname, 'w', encoding='utf-8') as f:  # charmap' codec can't encode character
        toml_str = toml.dump(tool_toml, f)
        
    # toml_str = toml.dumps(tool_toml)
    return toml_str
    
def extract_tool_info(section):

    tool_info = {}
    section_id = section.get('id')
    # print("section_id:", section_id)
    
    h2 = section.find("h2")
    
    if h2:  # Check if an h2 element was found

        paragraph = section.find("p")
        if paragraph:
            paragraphs = extract_paragraphs_before(section, 'parameters')
 
            if len(paragraphs) > 0:
                tool_info['brief_description'] = paragraphs[0]
                # print("Tool description:", tool_info['brief_description'])  
            else: 
                tool_info['brief_description'] = ""
            tool_info['tool_name'] = h2.get_text(strip=True)[:-1].split(".")[-1] 
            tool_info['paragraphs'] = paragraphs
  
        algorithm_id = None 
        python_code_snippet = None
        
        python_code_section = get_section_by_heading(section, 'h3', 'Python code')
        if python_code_section: 
            algorithm_id = python_code_section.find('code').get_text(strip=True)
            if not algorithm_id:
                return tool_info
            # print("algorithm_id:", algorithm_id) 
            pre_tag = python_code_section.find('pre')
            # print("python_code_section:", python_code_section)
            if pre_tag:
                python_code_snippet = pre_tag.get_text()
            # print("algorithm_id:", algorithm_id) 

        # store algorithm_id
        tool_info['algorithm_id'] = algorithm_id
        tool_info['python_code_snippet'] = python_code_snippet

        paremeters_section = get_section_by_heading(section, 'h3', 'Parameters')
        if paremeters_section:
            # print("paremeters_section:", paremeters_section)
            # basic_parameters_section = section.find('section', id='basic-parameters')   # only for 28.1.15. Raster analysis 
            # advanced_parameters_section = section.find('section', id='advanced-parameters') # only for 28.1.15. Raster analysis
            
            
            # basic_parameters = extract_table(basic_parameters_section) if basic_parameters_section else []  # only for 28.1.15. Raster analysis
            # advanced_parameters = extract_table(advanced_parameters_section) if advanced_parameters_section else []  # only for 28.1.15. Raster analysis
            parameters = extract_table(paremeters_section) if paremeters_section else [] 
            # print("parameters:", parameters)

            # tool_info['basic_parameters'] = basic_parameters   # only for 28.1.15. Raster analysis
            # tool_info['advanced_parameters'] = advanced_parameters   # only for 28.1.15. Raster analysis
            tool_info['parameters'] = parameters
            

        outputs_section = get_section_by_heading(section, 'h3', 'Outputs')
        if outputs_section:
            outputs = extract_table(outputs_section) if outputs_section else []
            tool_info['outputs'] = outputs
            # print("outputs:", outputs)

        # print(tool_info)
        # print("Tool description:", tool_info['brief_description'])  
        return tool_info
    else:
        # print("No h2 found in this section.")
        pass
        
    return tool_info


save_dir = r'D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\LLM_Geo\QGIS_plugin\toml'

count = 0

for section in sections[2:]:
    try:
        tool_info = extract_tool_info(section)    
        tool_name = tool_info['algorithm_id'].replace(":", "_")
        
        fname = os.path.join(save_dir, f"{tool_name}.toml")
        toml_str = make_TOML_file(tool_info, fname)
        # print("fname:", fname)
        count += 1

        print(f"{count} tool_name:", tool_name)

    except Exception as e:

        print("error:", e)
        pass

    # if count > 0: 
    #     break

# %% [markdown]
# # Download a url list

# %%
tools = ['Tessellate', 'Aspect', 'Assign projection', 'Buffer vectors', 'Build virtual raster', 'Build virtual vector', 'Clip raster by extent', 'Clip raster by mask layer', 'Clip vector by extent', 'Clip vector by mask layer', 'Color relief', 'Contour', 'Contour Polygons', 'Convert format', 'Dissolve', 'Execute SQL', 'Extract projection', 'Fill nodata', 'gdal2tiles', 'gdal2xyz', 'Raster information', 'Grid (Moving average)', 'Grid (Data metrics)', 'Grid (Inverse distance to a power)', 'Grid (IDW with nearest neighbor searching)', 'Grid (Linear)', 'Grid (Nearest neighbor)', 'Hillshade', 'Export to PostgreSQL (available connections)', 'Export to PostgreSQL (new connection)', 'Merge', 'Near black', 'Offset curve', 'Vector information', 'One side buffer', 'Build overviews (pyramids)', 'Pansharpening', 'PCT to RGB', 'Points along lines', 'Polygonize (raster to vector)', 'Proximity (raster distance)', 'Raster calculator', 'Rasterize (vector to raster)', 'Rasterize (overwrite with attribute)', 'Rasterize (overwrite with fixed value)', 'Rearrange bands', 'Retile', 'RGB to PCT', 'Roughness', 'Sieve', 'Slope', 'Tile index', 'Topographic Position Index (TPI)', 'Translate (convert format)', 'Terrain Ruggedness Index (TRI)', 'Viewshed', 'Warp (reproject)', 'g.extension.list', 'g.extension.manage', 'i.albedo', 'i.aster.toar', 'i.atcorr', 'i.biomass', 'i.cca', 'i.cluster', 'i.colors.enhance', 'i.eb.eta', 'i.eb.evapfr', 'i.eb.hsebal01.coords', 'i.eb.netrad', 'i.eb.soilheatflux', 'i.emissivity', 'i.evapo.mh', 'i.evapo.pm', 'i.evapo.pt', 'i.evapo.time', 'i.fft', 'i.gensig', 'i.gensigset', 'i.group', 'i.his.rgb', 'i.ifft', 'i.image.mosaic', 'i.in.spotvgt', 'i.landsat.acca', 'i.landsat.toar', 'i.maxlik', 'i.modis.qc', 'i.oif', 'i.pansharpen', 'i.pca', 'i.rgb.his', 'i.segment', 'i.smap', 'i.tasscap', 'i.topo.coor.ill', 'i.topo.corr', 'i.vi', 'i.zc', 'm.cogo', 'nviz', 'r.basins.fill', 'r.blend.combine', 'r.blend.rgb', 'r.buffer', 'r.buffer.lowmem', 'r.carve', 'r.category', 'r.category.out', 'r.circle', 'r.clump', 'r.coin', 'r.colors', 'r.colors.out', 'r.colors.stddev', 'r.composite', 'r.contour', 'r.cost', 'r.covar', 'r.cross', 'r.describe', 'r.distance', 'r.drain', 'r.fill.dir', 'r.fill.stats', 'r.fillnulls', 'r.flow', 'r.geomorphon', 'r.grow', 'r.grow.distance', 'r.gwflow', 'r.his', 'r.horizon', 'r.horizon.height', 'r.in.lidar', 'r.in.lidar.info', 'r.info', 'r.kappa', 'r.lake', 'r.latlong', 'r.li.cwed', 'r.li.cwed.ascii', 'r.li.dominance', 'r.li.dominance.ascii', 'r.li.edgedensity', 'r.li.edgedensity.ascii', 'r.li.mpa', 'r.li.mpa.ascii', 'r.li.mps', 'r.li.mps.ascii', 'r.li.padcv', 'r.li.padcv.ascii', 'r.li.padrange', 'r.li.padrange.ascii', 'r.li.padsd', 'r.li.padsd.ascii', 'r.li.patchdensity', 'r.li.patchdensity.ascii', 'r.li.patchnum', 'r.li.patchnum.ascii', 'r.li.pielou', 'r.li.pielou.ascii', 'r.li.renyi', 'r.li.renyi.ascii', 'r.li.richness', 'r.li.richness.ascii', 'r.li.shannon', 'r.li.shannon.ascii', 'r.li.shape', 'r.li.shape.ascii', 'r.li.simpson', 'r.li.simpson.ascii', 'r.mapcalc.simple', 'r.mask.rast', 'r.mask.vect', 'r.mfilter', 'r.mode', 'r.neighbors', 'r.null', 'r.out.ascii', 'r.out.gridatb', 'r.out.mat', 'r.out.mpeg', 'r.out.png', 'r.out.pov', 'r.out.ppm', 'r.out.ppm3', 'r.out.vrml', 'r.out.vtk', 'r.out.xyz', 'r.param.scale', 'r.patch', 'r.path', 'r.path.coordinate.txt', 'r.plane', 'r.profile', 'r.proj', 'r.quant', 'r.quantile', 'r.quantile.plain', 'r.random', 'r.random.cells', 'r.random.surface', 'r.reclass', 'r.reclass.area', 'r.recode', 'r.regression.line', 'r.regression.multi', 'r.relief', 'r.relief.scaling', 'r.report', 'r.resamp.bspline', 'r.resamp.filter', 'r.resamp.interp', 'r.resamp.rst', 'r.resamp.stats', 'r.resample', 'r.rescale', 'r.rescale.eq', 'r.rgb', 'r.ros', 'r.series', 'r.series.accumulate', 'r.series.interp', 'r.shade', 'r.sim.sediment', 'r.sim.water', 'r.slope.aspect', 'r.solute.transport', 'r.spread', 'r.spreadpath', 'r.statistics', 'r.stats', 'r.stats.quantile.out', 'r.stats.quantile.rast', 'r.stats.zonal', 'r.stream.extract', 'r.sun.incidout', 'r.sun.insoltime', 'r.sunhours', 'r.sunmask.datetime', 'r.sunmask.position', 'r.surf.area', 'r.surf.contour', 'r.surf.fractal', 'r.surf.gauss', 'r.surf.idw', 'r.surf.random', 'r.terraflow', 'r.texture', 'r.thin', 'r.tile', 'r.tileset', 'r.to.vect', 'r.topidx', 'r.topmodel', 'r.topmodel.topidxstats', 'r.transect', 'r.univar', 'r.uslek', 'r.usler', 'r.viewshed', 'r.volume', 'r.walk.coords', 'r.walk.points', 'r.walk.rast', 'r.water.outlet', 'r.watershed', 'r.what.color', 'r.what.coords', 'r.what.points', 'v.buffer', 'v.build.check', 'v.build.polylines', 'v.class', 'v.clean', 'v.cluster', 'v.db.select', 'v.decimate', 'v.delaunay', 'v.dissolve', 'v.distance', 'v.drape', 'v.edit', 'v.extract', 'v.extrude', 'v.generalize', 'v.hull', 'v.in.ascii', 'v.in.dxf', 'v.in.e00', 'v.in.geonames', 'v.in.lidar', 'v.in.lines', 'v.in.mapgen', 'v.in.wfs', 'v.info', 'v.kcv', 'v.kernel.rast', 'v.kernel.vector', 'v.lidar.correction', 'v.lidar.edgedetection', 'v.lidar.growing', 'v.mkgrid', 'v.neighbors', 'v.net', 'v.net.alloc', 'v.net.allpairs', 'v.net.bridge', 'v.net.centrality', 'v.net.components', 'v.net.connectivity', 'v.net.distance', 'v.net.flow', 'v.net.iso', 'v.net.nreport', 'v.net.path', 'v.net.report', 'v.net.salesman', 'v.net.spanningtree', 'v.net.steiner', 'v.net.timetable', 'v.net.visibility', 'v.normal', 'v.out.ascii', 'v.out.dxf', 'v.out.postgis', 'v.out.pov', 'v.out.svg', 'v.out.vtk', 'v.outlier', 'v.overlay', 'v.pack', 'v.parallel', 'v.patch', 'v.perturb', 'v.proj', 'v.qcount', 'v.random', 'v.rast.stats', 'v.reclass', 'v.rectify', 'v.report', 'v.sample', 'v.segment', 'v.select', 'v.split', 'v.surf.bspline', 'v.surf.idw', 'v.surf.rst', 'v.surf.rst.cvdev', 'v.to.3d', 'v.to.lines', 'v.to.points', 'v.to.rast', 'v.transform', 'v.type', 'v.univar', 'v.vect.stats', 'v.voronoi', 'v.voronoi.skeleton', 'v.what.rast', 'v.what.vect', 'Add autoincremental field', 'Add field to attributes table', 'Add unique value index field', 'Add X/Y fields to layer', 'Affine transform', 'Aggregate', 'Align rasters', 'Align raster', 'Align points to features', 'Geodesic line split at antimeridian', 'Array of offset (parallel) lines', 'Array of translated features', 'Aspect', 'Assign projection', 'Export atlas layout as image', 'Export atlas layout as PDF (multiple files)', 'Export atlas layout as PDF (single file)', 'Convert B3DM to GLTF', 'Batch Nominatim geocoder', 'Convert spatial bookmarks to layer', 'Boundary', 'Bounding boxes', 'Buffer', 'Variable width buffer (by M value)', 'Calculate expression', 'Overlap analysis', 'Create categorized renderer from styles', 'Cell stack percentile', 'Cell stack percentrank from raster layer', 'Cell stack percent rank from value', 'Cell statistics', 'Centroids', 'Clip', 'Collect geometries', 'Combine style databases', 'Concave hull', 'Conditional branch', 'Convert GPS data', 'Convert GPX feature type', 'Convert to curved geometries', 'Convex hull', 'Count points in polygon', 'Create attribute index', 'Create constant raster layer', 'Create directory', 'Create grid', 'Create points layer from table', 'Create random raster layer (binomial distribution)', 'Create random raster layer (exponential distribution)', 'Create random raster layer (gamma distribution)', 'Create random raster layer (geometric distribution)', 'Create random raster layer (negative binomial distribution)', 'Create random raster layer (normal distribution)', 'Create random raster layer (poisson distribution)', 'Create random raster layer (uniform distribution)', 'Create spatial index', 'DBSCAN clustering', 'Delaunay triangulation', 'Drop field(s)', 'Delete duplicate geometries', 'Delete holes', 'Densify by count', 'Densify by interval', 'Detect dataset changes', 'Difference', 'Dissolve', 'Download GPS data from device', 'Download vector tiles', 'Drop geometries', 'Drop M/Z values', 'DTM filter (slope-based)', 'Export layers to DXF', 'Equal to frequency', 'Explode HStore Field', 'Explode lines', 'Export layer(s) information', 'Export mesh edges', 'Export mesh faces', 'Export mesh on grid', 'Export mesh vertices', 'Export to spreadsheet', 'Extend lines', 'Create layer from extent', 'Extract binary field', 'Extract by attribute', 'Extract by expression', 'Extract/clip by extent', 'Extract by location', 'Extract labels', 'Extract M values', 'Extract specific vertices', 'Extract vertices', 'Extract within distance', 'Extract Z values', 'Field calculator', 'Download file', 'Fill NoData cells', 'Feature filter', 'Filter by geometry type', 'Filter layers by type', 'Filter vertices by M value', 'Filter vertices by Z value', 'Fix geometries', 'Flatten relationship', 'Force right-hand-rule', 'Fuzzify raster (gaussian membership)', 'Fuzzify raster (large membership)', 'Fuzzify raster (linear membership)', 'Fuzzify raster (near membership)', 'Fuzzify raster (power membership)', 'Fuzzify raster (small membership)', 'Generate points (pixel centroids) inside polygons', 'Geometry by expression', 'Convert GLTF to vector features', 'Greater than frequency', 'Highest position in raster stack', 'Hillshade', 'Join by lines (hub lines)', 'Export to PostgreSQL', 'Import geotagged photos', 'Interpolate point on line', 'Intersection', 'Join attributes by location', 'Join attributes by field value', 'Join attributes by location (summary)', 'Join attributes by nearest', 'Keep N biggest parts', 'K-means clustering', 'Convert layer to spatial bookmarks', 'Less than frequency', 'Line density', 'Line intersections', 'Line substring', 'Load layer into project', 'Lowest position in raster stack', 'Mean coordinate(s)', 'Merge lines', 'Merge vector layers', 'Export contours', 'Export cross section dataset values on lines from mesh', 'Export time series values from points of a mesh dataset', 'Rasterize mesh dataset', 'Minimum enclosing circles', 'Raster calculator', 'Raster calculator (virtual)', 'Difference (multiple)', 'Intersection (multiple)', 'Multipart to singleparts', 'Multi-ring buffer (constant distance)', 'Union (multiple)', 'Nearest neighbour analysis', 'Offset lines', 'Order by expression', 'Oriented minimum bounding box', 'Orthogonalize', 'Package layers', 'Raster pixels to points', 'Raster pixels to polygons', 'Point on surface', 'Points along geometry', 'Points to path', 'Create layer from point', 'Pole of inaccessibility', 'Extract layer extent', 'Polygonize', 'Polygons to lines', 'PostgreSQL execute SQL', 'Print layout map extent to layer', 'Export print layout as image', 'Export print layout as PDF', 'Project points (Cartesian)', 'Promote to multipart', 'Raise exception', 'Raise message', 'Raise warning', 'Random extract', 'Random points in extent', 'Random points in polygons', 'Random points on lines', 'Raster boolean AND', 'Raster calculator', 'Convert map to raster', 'Raster layer properties', 'Raster layer statistics', 'Raster layer unique values report', 'Raster layer zonal statistics', 'Raster boolean OR', 'Sample raster values', 'Raster surface volume', 'Reclassify by layer', 'Reclassify by table', 'Rectangles, ovals, diamonds', 'Refactor fields', 'Delete duplicates by attribute', 'Remove duplicate vertices', 'Remove null geometries', 'Rename layer', 'Rename field', 'Repair Shapefile', 'Reproject layer', 'Rescale raster', 'Retain fields', 'Reverse line direction', 'Rotate', 'Roundness', 'Round raster', 'Ruggedness index', 'Save vector features to file', 'Save log to file', 'Extract selected features', 'Segmentize by maximum angle', 'Segmentize by maximum distance', 'Select by location', 'Select within distance', 'Service area (from layer)', 'Service area (from point)', 'Set layer encoding', 'Set layer style', 'Set M value from raster', 'Set M value', 'Set project variable', 'Drape (set Z value from raster)', 'Set Z value', 'Shortest line between features', 'Shortest path (layer to point)', 'Shortest path (point to layer)', 'Shortest path (point to point)', 'Extract Shapefile encoding', 'Simplify', 'Single sided buffer', 'Slope', 'Smooth', 'Snap geometries to layer', 'Snap points to grid', 'SpatiaLite execute SQL', 'SpatiaLite execute SQL (registered DB)', 'Split features by character', 'Split lines by maximum length', 'Split vector layer', 'Split with lines', 'ST-DBSCAN clustering', 'String concatenation', 'Create style database from project', 'Subdivide', 'Sum line lengths', 'Swap X and Y coordinates', 'Symmetrical difference', 'Tapered buffers', 'Generate XYZ tiles (Directory)', 'Generate XYZ tiles (MBTiles)', 'TIN Mesh Creation', 'Transect', 'Transfer annotations from main layer', 'Translate', 'Truncate table', 'Union', 'Upload GPS data to device', 'Raster calculator (virtual)', 'Voronoi polygons', 'Create wedge buffers', 'Write Vector Tiles (MBTiles)', 'Write Vector Tiles (XYZ)', 'Zonal histogram', 'Zonal statistics (in place)', 'Zonal statistics', 'Assign projection', 'Boundary', 'Clip', 'Convert format', 'Create COPC', 'Density', 'Export to raster', 'Export to raster (using triangulation)', 'Export to vector', 'Filter', 'Information', 'Merge', 'Reproject', 'Thin (by skipping points)', 'Thin (by sampling radius)', 'Tile', 'Build virtual point cloud (VPC)', 'Advanced Python field calculator', 'Bar plot', 'Basic statistics for fields', 'Box plot', 'Check validity', 'Climb along line', 'Convert geometry type', 'Define Shapefile projection', 'Distance matrix', 'Distance to nearest hub (line to hub)', 'Distance to nearest hub (points)', 'Eliminate selected polygons', 'Execute SQL', 'Add geometry attributes', 'Find projection', 'Generate points (pixel centroids) along line', 'Heatmap (Kernel Density Estimation)', 'Hypsometric curves', 'IDW interpolation', 'Export to SpatiaLite', 'Concave hull (k-nearest neighbor)', 'Lines to polygons', 'List unique values', 'Mean and standard deviation plot', 'Minimum bounding geometry', 'Points displacement', 'Polar plot', 'PostgreSQL execute and load SQL', 'Random extract within subsets', 'Random points along line', 'Random points in layer bounds', 'Random points inside polygons', 'Random selection', 'Random selection within subsets', 'Raster calculator', 'Raster layer histogram', 'Rectangles, ovals, diamonds (variable)', 'Regular points', 'Relief', 'Vector layer scatterplot 3D', 'Select by attribute', 'Select by expression', 'Set style for raster layer', 'Set style for vector layer', 'Statistics by categories', 'Text to float', 'TIN interpolation', 'Topological coloring', 'Variable distance buffer', 'Vector layer histogram', 'Vector layer scatterplot']
len(tools)

# %%
GRASS_tools =["g.extension.list", "g.extension.manage", "i.albedo", "i.aster.toar", "i.atcorr", "i.biomass", "i.cca", "i.cluster", "i.colors.enhance", "i.eb.eta", "i.eb.evapfr", "i.eb.hsebal01.coords", "i.eb.netrad", "i.eb.soilheatflux", "i.emissivity", "i.evapo.mh", "i.evapo.pm", "i.evapo.pt", "i.evapo.time", "i.fft", "i.gensig", "i.gensigset", "i.group", "i.his.rgb", "i.ifft", "i.image.mosaic", "i.in.spotvgt", "i.landsat.acca", "i.landsat.toar", "i.maxlik", "i.modis.qc", "i.oif", "i.pansharpen", "i.pca", "i.rgb.his", "i.segment", "i.smap", "i.tasscap", "i.topo.coor.ill", "i.topo.corr", "i.vi", "i.zc", "m.cogo", "nviz", "r.basins.fill", "r.blend.combine", "r.blend.rgb", "r.buffer", "r.buffer.lowmem", "r.carve", "r.category", "r.category.out", "r.circle", "r.clump", "r.coin", "r.colors", "r.colors.out", "r.colors.stddev", "r.composite", "r.contour", "r.cost", "r.covar", "r.cross", "r.describe", "r.distance", "r.drain", "r.fill.dir", "r.fill.stats", "r.fillnulls", "r.flow", "r.geomorphon", "r.grow", "r.grow.distance", "r.gwflow", "r.his", "r.horizon", "r.horizon.height", "r.in.lidar", "r.in.lidar.info", "r.info", "r.kappa", "r.lake", "r.latlong", "r.li.cwed", "r.li.cwed.ascii", "r.li.dominance", "r.li.dominance.ascii", "r.li.edgedensity", "r.li.edgedensity.ascii", "r.li.mpa", "r.li.mpa.ascii", "r.li.mps", "r.li.mps.ascii", "r.li.padcv", "r.li.padcv.ascii", "r.li.padrange", "r.li.padrange.ascii", "r.li.padsd", "r.li.padsd.ascii", "r.li.patchdensity", "r.li.patchdensity.ascii", "r.li.patchnum", "r.li.patchnum.ascii", "r.li.pielou", "r.li.pielou.ascii", "r.li.renyi", "r.li.renyi.ascii", "r.li.richness", "r.li.richness.ascii", "r.li.shannon", "r.li.shannon.ascii", "r.li.shape", "r.li.shape.ascii", "r.li.simpson", "r.li.simpson.ascii", "r.mapcalc.simple", "r.mask.rast", "r.mask.vect", "r.mfilter", "r.mode", "r.neighbors", "r.null", "r.out.ascii", "r.out.gridatb", "r.out.mat", "r.out.mpeg", "r.out.png", "r.out.pov", "r.out.ppm", "r.out.ppm3", "r.out.vrml", "r.out.vtk", "r.out.xyz", "r.param.scale", "r.patch", "r.path", "r.path.coordinate.txt", "r.plane", "r.profile", "r.proj", "r.quant", "r.quantile", "r.quantile.plain", "r.random", "r.random.cells", "r.random.surface", "r.reclass", "r.reclass.area", "r.recode", "r.regression.line", "r.regression.multi", "r.relief", "r.relief.scaling", "r.report", "r.resamp.bspline", "r.resamp.filter", "r.resamp.interp", "r.resamp.rst", "r.resamp.stats", "r.resample", "r.rescale", "r.rescale.eq", "r.rgb", "r.ros", "r.series", "r.series.accumulate", "r.series.interp", "r.shade", "r.sim.sediment", "r.sim.water", "r.slope.aspect", "r.solute.transport", "r.spread", "r.spreadpath", "r.statistics", "r.stats", "r.stats.quantile.out", "r.stats.quantile.rast", "r.stats.zonal", "r.stream.extract", "r.sun.incidout", "r.sun.insoltime", "r.sunhours", "r.sunmask.datetime", "r.sunmask.position", "r.surf.area", "r.surf.contour", "r.surf.fractal", "r.surf.gauss", "r.surf.idw", "r.surf.random", "r.terraflow", "r.texture", "r.thin", "r.tile", "r.tileset", "r.to.vect", "r.topidx", "r.topmodel", "r.topmodel.topidxstats", "r.transect", "r.univar", "r.uslek", "r.usler", "r.viewshed", "r.volume", "r.walk.coords", "r.walk.points", "r.walk.rast", "r.water.outlet", "r.watershed", "r.what.color", "r.what.coords", "r.what.points", "v.buffer", "v.build.check", "v.build.polylines", "v.class", "v.clean", "v.cluster", "v.db.select", "v.decimate", "v.delaunay", "v.dissolve", "v.distance", "v.drape", "v.edit", "v.extract", "v.extrude", "v.generalize", "v.hull", "v.in.ascii", "v.in.dxf", "v.in.e00", "v.in.geonames", "v.in.lidar", "v.in.lines", "v.in.mapgen", "v.in.wfs", "v.info", "v.kcv", "v.kernel.rast", "v.kernel.vector", "v.lidar.correction", "v.lidar.edgedetection", "v.lidar.growing", "v.mkgrid", "v.neighbors", "v.net", "v.net.alloc", "v.net.allpairs", "v.net.bridge", "v.net.centrality", "v.net.components", "v.net.connectivity", "v.net.distance", "v.net.flow", "v.net.iso", "v.net.nreport", "v.net.path", "v.net.report", "v.net.salesman", "v.net.spanningtree", "v.net.steiner", "v.net.timetable", "v.net.visibility", "v.normal", "v.out.ascii", "v.out.dxf", "v.out.postgis", "v.out.pov", "v.out.svg", "v.out.vtk", "v.outlier", "v.overlay", "v.pack", "v.parallel", "v.patch", "v.perturb", "v.proj", "v.qcount", "v.random", "v.rast.stats", "v.reclass", "v.rectify", "v.report", "v.sample", "v.segment", "v.select", "v.split", "v.surf.bspline", "v.surf.idw", "v.surf.rst", "v.surf.rst.cvdev", "v.to.3d", "v.to.lines", "v.to.points", "v.to.rast", "v.transform", "v.type", "v.univar", "v.vect.stats", "v.voronoi", "v.voronoi.skeleton", "v.what.rast", "v.what.vect"]

# %%
for t in GRASS_tools:
    print(t)

# %% [markdown]
# # Grass Tools

# %%
GRASS_tools =["g.extension.list", "g.extension.manage", "i.albedo", "i.aster.toar", "i.atcorr", "i.biomass", "i.cca", "i.cluster", "i.colors.enhance", "i.eb.eta", "i.eb.evapfr", "i.eb.hsebal01.coords", "i.eb.netrad", "i.eb.soilheatflux", "i.emissivity", "i.evapo.mh", "i.evapo.pm", "i.evapo.pt", "i.evapo.time", "i.fft", "i.gensig", "i.gensigset", "i.group", "i.his.rgb", "i.ifft", "i.image.mosaic", "i.in.spotvgt", "i.landsat.acca", "i.landsat.toar", "i.maxlik", "i.modis.qc", "i.oif", "i.pansharpen", "i.pca", "i.rgb.his", "i.segment", "i.smap", "i.tasscap", "i.topo.coor.ill", "i.topo.corr", "i.vi", "i.zc", "m.cogo", "nviz", "r.basins.fill", "r.blend.combine", "r.blend.rgb", "r.buffer", "r.buffer.lowmem", "r.carve", "r.category", "r.category.out", "r.circle", "r.clump", "r.coin", "r.colors", "r.colors.out", "r.colors.stddev", "r.composite", "r.contour", "r.cost", "r.covar", "r.cross", "r.describe", "r.distance", "r.drain", "r.fill.dir", "r.fill.stats", "r.fillnulls", "r.flow", "r.geomorphon", "r.grow", "r.grow.distance", "r.gwflow", "r.his", "r.horizon", "r.horizon.height", "r.in.lidar", "r.in.lidar.info", "r.info", "r.kappa", "r.lake", "r.latlong", "r.li.cwed", "r.li.cwed.ascii", "r.li.dominance", "r.li.dominance.ascii", "r.li.edgedensity", "r.li.edgedensity.ascii", "r.li.mpa", "r.li.mpa.ascii", "r.li.mps", "r.li.mps.ascii", "r.li.padcv", "r.li.padcv.ascii", "r.li.padrange", "r.li.padrange.ascii", "r.li.padsd", "r.li.padsd.ascii", "r.li.patchdensity", "r.li.patchdensity.ascii", "r.li.patchnum", "r.li.patchnum.ascii", "r.li.pielou", "r.li.pielou.ascii", "r.li.renyi", "r.li.renyi.ascii", "r.li.richness", "r.li.richness.ascii", "r.li.shannon", "r.li.shannon.ascii", "r.li.shape", "r.li.shape.ascii", "r.li.simpson", "r.li.simpson.ascii", "r.mapcalc.simple", "r.mask.rast", "r.mask.vect", "r.mfilter", "r.mode", "r.neighbors", "r.null", "r.out.ascii", "r.out.gridatb", "r.out.mat", "r.out.mpeg", "r.out.png", "r.out.pov", "r.out.ppm", "r.out.ppm3", "r.out.vrml", "r.out.vtk", "r.out.xyz", "r.param.scale", "r.patch", "r.path", "r.path.coordinate.txt", "r.plane", "r.profile", "r.proj", "r.quant", "r.quantile", "r.quantile.plain", "r.random", "r.random.cells", "r.random.surface", "r.reclass", "r.reclass.area", "r.recode", "r.regression.line", "r.regression.multi", "r.relief", "r.relief.scaling", "r.report", "r.resamp.bspline", "r.resamp.filter", "r.resamp.interp", "r.resamp.rst", "r.resamp.stats", "r.resample", "r.rescale", "r.rescale.eq", "r.rgb", "r.ros", "r.series", "r.series.accumulate", "r.series.interp", "r.shade", "r.sim.sediment", "r.sim.water", "r.slope.aspect", "r.solute.transport", "r.spread", "r.spreadpath", "r.statistics", "r.stats", "r.stats.quantile.out", "r.stats.quantile.rast", "r.stats.zonal", "r.stream.extract", "r.sun.incidout", "r.sun.insoltime", "r.sunhours", "r.sunmask.datetime", "r.sunmask.position", "r.surf.area", "r.surf.contour", "r.surf.fractal", "r.surf.gauss", "r.surf.idw", "r.surf.random", "r.terraflow", "r.texture", "r.thin", "r.tile", "r.tileset", "r.to.vect", "r.topidx", "r.topmodel", "r.topmodel.topidxstats", "r.transect", "r.univar", "r.uslek", "r.usler", "r.viewshed", "r.volume", "r.walk.coords", "r.walk.points", "r.walk.rast", "r.water.outlet", "r.watershed", "r.what.color", "r.what.coords", "r.what.points", "v.buffer", "v.build.check", "v.build.polylines", "v.class", "v.clean", "v.cluster", "v.db.select", "v.decimate", "v.delaunay", "v.dissolve", "v.distance", "v.drape", "v.edit", "v.extract", "v.extrude", "v.generalize", "v.hull", "v.in.ascii", "v.in.dxf", "v.in.e00", "v.in.geonames", "v.in.lidar", "v.in.lines", "v.in.mapgen", "v.in.wfs", "v.info", "v.kcv", "v.kernel.rast", "v.kernel.vector", "v.lidar.correction", "v.lidar.edgedetection", "v.lidar.growing", "v.mkgrid", "v.neighbors", "v.net", "v.net.alloc", "v.net.allpairs", "v.net.bridge", "v.net.centrality", "v.net.components", "v.net.connectivity", "v.net.distance", "v.net.flow", "v.net.iso", "v.net.nreport", "v.net.path", "v.net.report", "v.net.salesman", "v.net.spanningtree", "v.net.steiner", "v.net.timetable", "v.net.visibility", "v.normal", "v.out.ascii", "v.out.dxf", "v.out.postgis", "v.out.pov", "v.out.svg", "v.out.vtk", "v.outlier", "v.overlay", "v.pack", "v.parallel", "v.patch", "v.perturb", "v.proj", "v.qcount", "v.random", "v.rast.stats", "v.reclass", "v.rectify", "v.report", "v.sample", "v.segment", "v.select", "v.split", "v.surf.bspline", "v.surf.idw", "v.surf.rst", "v.surf.rst.cvdev", "v.to.3d", "v.to.lines", "v.to.points", "v.to.rast", "v.transform", "v.type", "v.univar", "v.vect.stats", "v.voronoi", "v.voronoi.skeleton", "v.what.rast", "v.what.vect"]

# %%
for idx, tool in enumerate(GRASS_tools):
    print(f"Processing: {idx + 1} / {len(GRASS_tools)}, {t} ")
    url = f"https://grass.osgeo.org/grass84/manuals/{tool}.html"
    print("    URL:", url)
    
    
    print()
    
    if idx > 2:
        break

# %%
soup = get_response(url)
url

# %%
from bs4 import BeautifulSoup
import json

# Sample HTML (In a real case, you would read this from an HTML file)
 

# Parse the HTML content
# soup = BeautifulSoup(html_content, 'html.parser')

# Dictionary to hold headers and associated text content
content_dict = {}

# Function to assemble text under each header, including non-tag inline text
def get_associated_content(header):
    content = []
    next_sibling = header.find_next_sibling()

    while next_sibling and next_sibling.name not in ['h2', 'h3', 'h4']:
        # Handle elements with tags
        if next_sibling.name in ['a', 'p', 'em', 'div',  'b', 'dd', 'dt', 'dl']:
            content.append(next_sibling.get_text(strip=True))
        # Handle inline text outside of tags
        if next_sibling.next_sibling and isinstance(next_sibling.next_sibling, str):
            content.append(next_sibling.next_sibling.strip())
        next_sibling = next_sibling.find_next_sibling()

    # Join everything together in paragraph form
    return ' '.join(content)

# Extract headers and assemble content for each section
for header in soup.find_all(['h2', 'h3', 'h4']):
    header_text = header.get_text(strip=True)
    paragraph = get_associated_content(header)
    if paragraph:
        content_dict[header_text] = paragraph

# Save the result to a JSON file
with open('assembled_content.json', 'w') as json_file:
    json.dump(content_dict, json_file, indent=4)

print("Content assembled and saved to assembled_content.json")

# %%
from bs4 import BeautifulSoup
import json

soup = get_response(url)

# Dictionary to hold headers and associated paragraphs
content_dict = {}

# Function to assemble text under each header, including non-tag inline text
def get_associated_content(header):
    content = []
    next_sibling = header.find_next_sibling()
    
    # print("next_sibling:", next_sibling)

    # Loop through sibling elements until another header tag is encountered
#     while next_sibling and next_sibling.name not in ['h2', 'h3', 'h4']:
#         # Handle elements with tags
#         if next_sibling and next_sibling.name in ['a', 'p', 'div', 'em', 'b', 'dd', 'dt']:
#             content.append(next_sibling.get_text(strip=True))
#         # Handle inline text outside of tags
#         if next_sibling and isinstance(next_sibling, str):
#             content.append(next_sibling.strip(strip=True))
#         # Move to the next sibling (tag or text node)
#         next_sibling = next_sibling.find_next_sibling()
        
    while next_sibling and next_sibling.name not in ['h2', 'h3', 'h4']:
        # Handle elements with tags
        if next_sibling.name in ['a', 'p', 'em', 'div',  'b', 'dd', 'dt', 'dl']:
            content.append(next_sibling.get_text(strip=True))
        # Handle inline text outside of tags
        if next_sibling.next_sibling and isinstance(next_sibling.next_sibling, str):
            content.append(next_sibling.next_sibling.strip())
        next_sibling = next_sibling.find_next_sibling()


    # Join everything together in paragraph form
    return ' '.join(content)

# Variables to store current hierarchy level
current_h2 = None
current_h3 = None

# Extract headers (h2, h3, h4) and their associated paragraphs
# Iterate through all headers (h2, h3, h4)
for header in soup.find_all(['h2', 'h3', 'h4']):
    header_text = header.get_text(strip=True)
    paragraph = get_associated_content(header)
    
    # print("header.name:", header.name, header_text)
    # print("paragraph:", paragraph)
    
    if header.name == 'h2':
        # Create a new h2 entry
        content_dict[header_text] = {}
        current_h2 = header_text
        current_h3 = None  # Reset h3 context
        content_dict[current_h2] = {}
        content_dict[current_h2]['paragraphs'] = paragraph
        print("header.name:", header.name, current_h2)
        # print("paragraph:", paragraph)

    elif header.name == 'h3' and current_h2:
        # Create a new h3 entry under the current h2
        # content_dict[current_h2][header_text] = {}
        current_h3 = header_text
        # print("content_dict:", content_dict[current_h2])
        print("header.name:", header.name, current_h3)
        content_dict[current_h2][current_h3] = paragraph

#     elif header.name == 'h4' and current_h2 and current_h3:
#         # Create a new h4 entry under the current h3
#         content_dict[current_h2][current_h3][header_text] = paragraph

# for header in soup.find_all(['h2', 'h3', 'h4']):
#     header_text = header.get_text(strip=True)
#     paragraph = get_associated_content(header)
#     if paragraph:
#         content_dict[header_text] = paragraph

        
# Save the result to a JSON file
with open('headers_and_paragraphs.json', 'w') as json_file:
    json.dump(content_dict, json_file, indent=4)

print("Headers and paragraphs extracted and saved to headers_and_paragraphs.json")

# %%
from bs4 import BeautifulSoup
import json


# Function to assemble text under each header, including non-tag inline text
def get_associated_content(header):
    content = []
    next_sibling = header.find_next_sibling()

    # Loop through sibling elements until another header tag (h2, h3, h4) is encountered
    while next_sibling and next_sibling.name not in ['h2', 'h3', 'h4']:
        # Handle elements with tags
        if next_sibling.name in ['a', 'p', 'div', 'em', 'b', 'dd', 'dt']:
            content.append(next_sibling.get_text(strip=True))
        # Handle inline text outside of tags
        if next_sibling.next_sibling and isinstance(next_sibling.next_sibling, str):
            content.append(next_sibling.next_sibling.strip())
        next_sibling = next_sibling.find_next_sibling()

    # Join everything together in paragraph form
    return ' '.join(content)

# Recursive function to process headers and their subheaders
def process_headers(header):
    result = {}
    header_text = header.get_text(strip=True)
    paragraph = get_associated_content(header)

    # Store the paragraph content
    result["content"] = paragraph

    # Recursively process subheaders
    next_sibling = header.find_next_sibling()
    while next_sibling and next_sibling.name != 'h2':  # Stop when encountering the next h2 header
        if next_sibling.name == 'h3':
            result[next_sibling.get_text(strip=True)] = process_headers(next_sibling)
        if next_sibling.name == 'h4':
            result[next_sibling.get_text(strip=True)] = process_headers(next_sibling)
        next_sibling = next_sibling.find_next_sibling()

    return result

# Main dictionary to store all headers and subheaders
content_dict = {}

# Extract and process all h2 headers and recursively process their subheaders
for header in soup.find_all('h2'):
    content_dict[header.get_text(strip=True)] = process_headers(header)

# Save the result to a JSON file
with open('headers_and_subheaders_recursive.json', 'w') as json_file:
    json.dump(content_dict, json_file, indent=4)

print("Headers and subheaders extracted and saved to headers_and_subheaders_recursive.json")

# %% [markdown]
# # By header

# %%
from bs4 import BeautifulSoup
import json
import copy
import pprint

url = r'https://grass.osgeo.org/grass84/manuals/i.aster.toar.html'

soup = get_response(url)

# %%
# Dictionary to hold headers and their associated content
content_dict = {}


# grass_html = Extract_GRASS_doc(soup)
 

def get_name_content(header, tool_info):
    
    next_sibling = header.find_next_sibling()
    
    while next_sibling and next_sibling.name not in ['h2', 'h3', 'h4']:
        if next_sibling.name in ['a', 'p', 'em', 'div',  'b', 'dd', 'dt', 'dl', 'pre']:
            sibling_text = next_sibling.get_text(strip=True)
            tool_info['name'] = sibling_text
            
        # Handle inline text outside of tags
        if next_sibling.next_sibling and isinstance(next_sibling.next_sibling, str):
            sibling_text = next_sibling.next_sibling.strip()
            tool_info['brief_description'] = sibling_text[2:] # remove the starting "- ". 
            
        next_sibling = next_sibling.find_next_sibling()        
             
    return tool_info

def get_keywords_content(header, tool_info):
    keywords = []
    next_sibling = header.find_next_sibling()
    
    while next_sibling and next_sibling.name not in ['h2', 'h3', 'h4']:
        if next_sibling.name in ['a', 'p', 'em', 'div',  'b', 'dd', 'dt', 'dl', 'pre']:
            sibling_text = next_sibling.get_text(strip=True)            
            keywords.append(sibling_text) 
            
        next_sibling = next_sibling.find_next_sibling()  
    tool_info['keywords'] = keywords
             
    return tool_info

def get_synopsis_content(header, tool_info):
    content_lines = []
    
    # get tool name
    next_sibling = header.find_next_sibling()
    sibling_text = next_sibling.get_text(strip=True)    
    content_lines.append(sibling_text)
    
    # get tool --help
    next_sibling = next_sibling.find_next_sibling()    
    sibling_text = next_sibling.get_text(strip=True)    
    content_lines.append(sibling_text)
    
    
    next_sibling = next_sibling.find_next_sibling() # skip a <br>
    
    # get tool command    
    next_sibling = next_sibling.find_next_sibling()    
    sibling_text = next_sibling.get_text(strip=True)    
    content_lines.append(sibling_text)
     
    tool_info['synopsis'] = content_lines
             
    return tool_info

def get_flags_content(header, tool_info):
    content_dict = {}    
    next_sibling = header.find_next_sibling()  
    dl = next_sibling.find('dl')
    # Iterate over <dt> and <dd> tags
    for dt in next_sibling.find_all('dt'):
        term = dt.get_text(strip=True)  # Get the text in <dt>
        dd = dt.find_next_sibling('dd')  # Get the corresponding <dd>
        if dd:
            description = dd.get_text(strip=True)  # Get the text in <dd>
            content_dict[term] = description
     
    tool_info['Flags'] = content_dict
             
    return tool_info

def get_parameters_content(header, tool_info):
    content_dict = {}    
    next_sibling = header.find_next_sibling()  
    dl = next_sibling.find('dl')
    # Iterate over <dt> and <dd> tags
    for dt in next_sibling.find_all('dt'):
        term = dt.get_text(strip=True)  # Get the text in <dt>
        dd = dt.find_next_sibling('dd')  # Get the corresponding <dd>
        if dd:
            description = dd.get_text(strip=True)  # Get the text in <dd>
            content_dict[term] = description
     
    tool_info['Parameters'] = content_dict
             
    return tool_info

def get_description_content(header, tool_info):
    paragraphs = []
    paragraph = ""
    next_sibling = header.next_sibling
    # print("next_sibling:", next_sibling.name, next_sibling.get_text(strip=True))
    # print("next_sibling:", next_sibling.name, next_sibling.get_text(strip=True))
    
    while next_sibling and next_sibling.name not in ['h2']:
        if next_sibling.name in ['a', 'em', 'div',  'b', 'dd', 'dt', 'dl', 'pre']:
            # print("next_sibling.name:", next_sibling.name)
            sibling_text = next_sibling.get_text(strip=True)            
            paragraph += sibling_text            
            # print("type of next_sibling:", type(next_sibling))
            # print("sibling_text:", sibling_text)
            
        # if next_sibling.next_sibling and isinstance(next_sibling.next_sibling, str):
        if isinstance(next_sibling, str):
            sibling_text = next_sibling.get_text().replace('\n', '')
            
            # print("      string， sibling_text:", sibling_text)
            
            if next_sibling.next_sibling.name in ["h2", "h3", "h4"]:
                paragraphs.append(sibling_text)
                # print("paragraphs:", paragraphs)
                
            else:
                
                paragraph += sibling_text
            # print("string， sibling_text:", sibling_text)
            # print("type of next_sibling.next_sibling:", type(next_sibling.next_sibling))
            # print(" next_sibling.next_sibling:", next_sibling.next_sibling)
             
            # next_sibling.next_sibling
            # print("next_sibling.name:", next_sibling.name)
            # print("paragraphs:", paragraphs)
            
        if next_sibling.name in ['p']:
            sibling_text = next_sibling.get_text(strip=True)   
            paragraphs.append(paragraph)
            
            # print("paragraphs:", paragraphs)
            # print("p， paragraph:", paragraph)
            paragraph = ""
            paragraphs.append(sibling_text)            
            # print("sibling_text:", sibling_text)
            # print("paragraphs:", paragraphs)
            
             
        if next_sibling.name in ['ul']:
            
            if paragraph:
                paragraphs.append(paragraph)
                # print("paragraphs:", paragraphs)
                paragraph = ""
            
            sibling_text = next_sibling.get_text(strip=False)
            ulist = sibling_text.split('\n')
            
            # print("ulist:", ulist            
            # remove emptry strings
            ulist = [f"•{item}" for item in ulist if item]  # correct
            # print("ulist:", ulist)
            # ulist = [ for item in ulist if item]
            
            # print("paragraphs:", paragraphs)
            
            paragraphs += ulist
            
            # paragraphs.append(sibling_text)
            # print("paragraphs:", paragraphs)
              
        # next_sibling = next_sibling.find_next_sibling()  # cannot find strings that are not enclosed in tags
        next_sibling = next_sibling.next_sibling  # can find strings that are not enclosed in tags
        # print("next_sibling:", next_sibling.name, next_sibling.get_text(strip=True))
        
        
    tool_info['description'] = paragraphs
             
    return tool_info
 
    
def get_notes_content(header, tool_info):
    paragraphs = []
    paragraph = ""
    next_sibling = header.next_sibling
    # print("next_sibling:", next_sibling.name, next_sibling.get_text(strip=True))
    
    while next_sibling and next_sibling.name not in ['h2', 'h3', 'h4']:
        if next_sibling.name in ['a', 'em',  'b', 'dd', 'dt', 'dl']:
            sibling_text = next_sibling.get_text(strip=True)            
            paragraph += sibling_text             
            
        if isinstance(next_sibling, str):
            sibling_text = next_sibling.get_text().replace('\n', '')
            
            # print("     string next_sibling:", next_sibling.name, next_sibling.get_text(strip=True))
            
            if next_sibling.next_sibling.name in ["h2", "h3", "h4"]:
                paragraphs.append(sibling_text)               
            else:                
                paragraph += sibling_text
                
            if next_sibling.next_sibling.name in ['pre', 'h2', 'h3', 'h4']:  # end
                paragraphs.append(paragraph) 
                paragraph = ""
            
        if next_sibling.name in ['p']:
            sibling_text = next_sibling.get_text(strip=True)   
            paragraphs.append(paragraph)            
            paragraph = ""
            paragraphs.append(sibling_text)            
            
        if next_sibling.name in ['div']:
            
            if paragraph:
                paragraphs.append(paragraph)
                # print("paragraphs:", paragraphs)
                paragraph = ""
            
            sibling_text = next_sibling.get_text(strip=False)
            # print("sibling_text:", sibling_text)
 
  
            # print("paragraphs:", paragraphs)
            
  
            paragraphs.append(sibling_text)
            # print("paragraphs:", paragraphs)
              
        # next_sibling = next_sibling.find_next_sibling()  # cannot find strings that are not enclosed in tags
        next_sibling = next_sibling.next_sibling  # can find strings that are not enclosed in tags
        # print("next_sibling:", next_sibling.name, next_sibling.get_text(strip=True))
        
    tool_info['notes'] = paragraphs
             
    return tool_info

def get_see_also_content(header, tool_info):
    links = []
    paragraphs = []
    next_sibling = header.find_next_sibling()
    # print("header:", header, header.name)
    # print("next_sibling:", next_sibling.name, next_sibling,  next_sibling.get_text(strip=True))
    # print("next_sibling:", header.find_next_sibling())
    
    while next_sibling and next_sibling.name not in ['h2', 'h3', 'h4']:
        if next_sibling.name in ['a', 'em']:
            sibling_text = next_sibling.get_text(strip=True)            
            links =   sibling_text.split(",")   
            paragraphs += links
            
        if next_sibling.name in ['p']:
            # sibling_text = next_sibling.get_text(strip=True)             
            convert_to_markdown(next_sibling)
                
            sibling_text = next_sibling.get_text(strip=True) 
            paragraphs.append(sibling_text)  
            
        next_sibling = next_sibling.find_next_sibling()  # cannot find strings that are not enclosed in tags
        
        # .next_sibling: This method only navigates the immediate next sibling node in the document. The sibling could be another tag, a text node, or even whitespace. If there is any text (including line breaks, spaces, etc.) between the <h2> and <em> tags, .next_sibling will return that text or whitespace instead of the <em> tag.
             
    tool_info['see_also'] = paragraphs
             
    return tool_info

# Function to convert HTML content to markdown
def convert_to_markdown(tag):
    # Convert links to markdown format
    for a_tag in tag.find_all('a'):
        link_text = a_tag.get_text()
        link_url = a_tag['href']
        # Replace the <a> tag with markdown-formatted link
        a_tag.replace_with(f'[{link_text}]({link_url})')
    
    # Return the markdown-converted paragraph text
    return tag.get_text()

 
def get_author_content(header, tool_info):
     
    next_sibling = header.next_sibling
    
    # print("next_sibling:", next_sibling.name, next_sibling,  next_sibling.get_text(strip=True))
    
    paragraphs = []
    paragraph = ""
    
    while next_sibling and next_sibling.name not in ['h2', 'h3', 'h4']:
    
        if isinstance(next_sibling, str):
            sibling_text = next_sibling.get_text(strip=True) # .replace('\n', '')
            paragraph += sibling_text
              
        next_sibling = next_sibling.next_sibling  # can find strings that are not enclosed in tags
        
    paragraphs.append(paragraph)         
    tool_info['author'] = paragraphs
             
    return tool_info

def get_source_code_content(header, tool_info):
     
    next_sibling = header.next_sibling
    
    # print("next_sibling:", next_sibling.name, next_sibling,  next_sibling.get_text(strip=True))
    
    paragraphs = []
    paragraph = ""
    
    while next_sibling and next_sibling.name not in ['h2', 'h3', 'h4', 'hr']:
    
        if isinstance(next_sibling, str):
            sibling_text = next_sibling.get_text(strip=True) # .replace('\n', '')
            paragraph += sibling_text
            
        if next_sibling.name in ['p']:
        
            convert_to_markdown(next_sibling)
                
            sibling_text = next_sibling.get_text(strip=True) 
            paragraphs.append(sibling_text)  
            
            # sibling_text = next_sibling.get_text(strip=True) # .replace('\n', '')
            # paragraph += sibling_text
              
        next_sibling = next_sibling.next_sibling  # can find strings that are not enclosed in tags
        
    paragraphs.append(paragraph)         
    tool_info['source_code'] = paragraphs
             
    return tool_info


tool_info = {}
for header in soup.find_all(['h2', 'h3', 'h4']):
    header_text = header.get_text(strip=True)
    
    print(header_text)     
    
    if header_text == 'NAME':
        get_name_content(header, tool_info)
        
    if header_text == 'KEYWORDS':
        get_keywords_content(header, tool_info)
        
    if header_text == 'SYNOPSIS':
        get_synopsis_content(header, tool_info)
        
    if header_text == 'Flags:':
        get_flags_content(header, tool_info)
        
    if header_text == 'DESCRIPTION':
        get_description_content(header, tool_info)
        
    if header_text == 'NOTES':
        get_notes_content(header, tool_info)
    
    if header_text == 'SEE ALSO':
        get_see_also_content(header, tool_info)
        
    if header_text == 'AUTHOR':
        get_author_content(header, tool_info)      
        
    if header_text == 'SOURCE CODE':
        get_source_code_content(header, tool_info)              
        
# pprint.pprint(tool_info, width=800)

# %%
for line in tool_info['source_code']:
    print(line)

# %%
for line in tool_info['author']:
    print(line)

# %%
for line in tool_info['see_also']:
    print(line)

# %%
for line in tool_info['notes']:
    print(line)

# %%
soup = beaufrequests.get(url).content

# %%
markdown_content = markdownify(str(t))
print(markdown_content)
# Out:
# #### Table of contents
#
#
# * [DESCRIPTION](#description)
# * [6S CODE PARAMETER CHOICES](#6s-code-parameter-choices)
# 	+ [A. Geometrical conditions](#a.-geometrical-conditions)
# 	+ [B. Atmospheric model](#b.-atmospheric-model)
# 	+ [C. Aerosols model](#c.-aerosols-model)
# 	+ [D. Aerosol concentration model (visibility)](#d.-aerosol-concentration-model-(visibility))
# 	+ [E. Target altitude (xps), sensor platform (xpp)](#e.-target-altitude-(xps),-sensor-platform-(xpp))
# 	+ [F. Sensor band](#f.-sensor-band)
# * [EXAMPLES](#examples)
# 	+ [Atmospheric correction of a Sentinel\-2 band](#atmospheric-correction-of-a-sentinel-2-band)
# 	+ [Atmospheric correction of a Landsat\-7 band](#atmospheric-correction-of-a-landsat-7-band)
# * [REMAINING DOCUMENTATION ISSUES](#remaining-documentation-issues)
# * [REFERENCES](#references)
# * [SEE ALSO](#see-also)
# * [AUTHORS](#authors)

# %%
soup = get_response(url)



# soup
t = soup.find(['div'], class_=['toc'])


# # Print the result
print(markdown_content)

# %%
# # ! pip install html2text
# ! pip install markdownify

# import html2text
from markdownify import markdownify


# html_content = """
# <h1>Title</h1>
# <p>This is a <strong>bold</strong> paragraph.</p>
# <a href="https://example.com">Link to Example</a>
# """

# # Convert HTML to Markdown
# markdown_content = html2text.html2text( requests.get(url).content)
from markdownify import markdownify
markdown_content = markdownify( requests.get(url).content)

# # Print the result
print(markdown_content)

# %%
soup

# %%
tool_info

# %%
# pprint.pprint(tool_info, width=800)
for line in tool_info['description']:
    print(line)

# len(soup.find_all("p"))
# soup.find_all("p")[0]

# %%
# class Extract_GRASS_doc:
#     def __init__(self, soup):
#         self.soup = soup        
        
#     def NAME(self):
#         return
    
#     def KEYWORDS(self):
#         return
    
#     def SYNOPSIS(self):
#         return
    
#     def Flags(self):
#         return
    
#     def Parameters(self):
#         return
    
#     def DESCRIPTION(self):
#         return
    
#     def SEE_ALSO(self):
#         return
 
#     def NOTES(self):
#         return    
    
#     def AUTHOR(self):
#         return
    
    
#     def SOURCE_CODE(self):
#         return    
    
    

    
#     # grass_html.NAME()
